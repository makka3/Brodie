# %%
import pandas as pd
import numpy as np
import time
import requests
from bs4 import BeautifulSoup
import re

# %%
westbrook = requests.get("https://www.basketball-reference.com/players/w/westbru01/gamelog/2016")

# %%
westbrook.status_code
# Out:
# 200

# %%
westbrook.headers
# Out:
# {'Date': 'Fri, 01 Nov 2019 00:43:40 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Keep-Alive': 'timeout=15', 'Vary': 'Accept-Encoding', 'SR-MISS-MEMD-KEY': '/players/w/westbru01/gamelog/2009', 'X-Accel-Expires': '28800', 'Source': 'back-1-bbr', 'X-cache-key-basic': 'www.basketball-reference.com/players/w/westbru01/gamelog/2009', 'X-Cache-Status': 'MISS', 'Content-Encoding': 'gzip'}

# %%
westbrook.text

# %%
russ = BeautifulSoup(westbrook.text,'lxml')

# %%
russ

# %%
games = russ.find("div", {"id": "all_pgl_basic"}).find_all('tr')

# %%
games

# %%
headers_list = []

for i in games[0].find_all('th'):
    entry = i.getText()
    headers_list.append(entry)

# %%
headers_list
# Out:
# ['Rk',
#  'G',
#  'Date',
#  'Age',
#  'Tm',
#  '\xa0',
#  'Opp',
#  '\xa0',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS',
#  'GmSc',
#  '+/-']

# %%
stats = []

for i in games[74].find_all('td'):
    stats.append(i.getText())

# %%
stats
# Out:
# ['71',
#  '2016-03-22',
#  '27-131',
#  'OKC',
#  '',
#  'HOU',
#  'W (+4)',
#  '1',
#  '36:52',
#  '7',
#  '18',
#  '.389',
#  '0',
#  '7',
#  '.000',
#  '7',
#  '8',
#  '.875',
#  '3',
#  '9',
#  '12',
#  '15',
#  '1',
#  '0',
#  '4',
#  '1',
#  '21',
#  '22.7',
#  '-5']

# %%
len(games)
# Out:
# 87

# %%
headers = []
season_stats = []

for w in games[0].find_all('th'):
    entry = w.getText()
    headers.append(entry)

for i in range(1,len(games)):
    game_stats = []
    for j in games[i].find_all('td'):
        game_stats.append(j.getText())
    season_stats.append(game_stats)

# %%
headers = headers[1:]

# %%
season_stats
# Out:
# [['1',
#   '2015-10-28',
#   '26-350',
#   'OKC',
#   '',
#   'SAS',
#   'W (+6)',
#   '1',
#   '36:59',
#   '12',
#   '23',
#   '.522',
#   '3',
#   '6',
#   '.500',
#   '6',
#   '7',
#   '.857',
#   '1',
#   '1',
#   '2',
#   '10',
#   '2',
#   '0',
#   '5',
#   '3',
#   '33',
#   '25.1',
#   '+7'],
#  ['2',
#   '2015-10-30',
#   '26-352',
#   'OKC',
#   '@',
#   'ORL',
#   'W (+3)',
#   '1',
#   '47:35',
#   '17',
#   '36',
#   '.472',
#   '1',
#   '5',
#   '.200',
#   '13',
#   '16',
#   '.813',
#   '5',
#   '6',
#   '11',
#   '8',
#   '1',
#   '1',
#   '6',
#   '3',
#   '48',
#   '33.8',
#   '+2'],
#  ['3',
#   '2015-11-01',
#   '26-354',
#   'OKC',
#   '',
#   'DEN',
#   'W (+24)',
#   '1',
#   '25:26',
#   '7',
#   '13',
#   '.538',
#   '1',
#   '4',
#   '.250',
#   '0',
#   '0',
#   '',
#   '2',
#   '7',
#   '9',
#   '8',
#   '3',
#   '0',
#   '4',
#   '0',
#   '15',
#   '16.8',
#   '+22'],
#  ['4',
#   '2015-11-02',
#   '26-355',
#   'OKC',
#   '@',
#   'HOU',
#   'L (-5)',
#   '1',
#   '31:57',
#   '10',
#   '16',
#   '.625',
#   '3',
#   '6',
#   '.500',
#   '2',
#   '2',
#   '1.000',
#   '2',
#   '6',
#   '8',
#   '11',
#   '2',
#   '0',
#   '7',
#   '5',
#   '25',
#   '21.7',
#   '+4'],
#  ['5',
#   '2015-11-04',
#   '26-357',
#   'OKC',
#   '',
#   'TOR',
#   'L (-5)',
#   '1',
#   '35:20',
#   '8',
#   '21',
#   '.381',
#   '3',
#   '9',
#   '.333',
#   '3',
#   '4',
#   '.750',
#   '0',
#   '5',
#   '5',
#   '16',
#   '2',
#   '0',
#   '8',
#   '4',
#   '22',
#   '15.2',
#   '+3'],
#  ['6',
#   '2015-11-05',
#   '26-358',
#   'OKC',
#   '@',
#   'CHI',
#   'L (-6)',
#   '1',
#   '38:34',
#   '7',
#   '18',
#   '.389',
#   '0',
#   '2',
#   '.000',
#   '6',
#   '6',
#   '1.000',
#   '2',
#   '6',
#   '8',
#   '10',
#   '1',
#   '0',
#   '2',
#   '2',
#   '20',
#   '18.6',
#   '+8'],
#  ['7',
#   '2015-11-08',
#   '26-361',
#   'OKC',
#   '',
#   'PHO',
#   'W (+21)',
#   '1',
#   '33:58',
#   '9',
#   '20',
#   '.450',
#   '0',
#   '3',
#   '.000',
#   '3',
#   '4',
#   '.750',
#   '4',
#   '2',
#   '6',
#   '13',
#   '4',
#   '0',
#   '2',
#   '3',
#   '21',
#   '23.5',
#   '+26'],
#  ['8',
#   '2015-11-10',
#   '26-363',
#   'OKC',
#   '@',
#   'WAS',
#   'W (+24)',
#   '1',
#   '27:46',
#   '7',
#   '17',
#   '.412',
#   '3',
#   '4',
#   '.750',
#   '5',
#   '6',
#   '.833',
#   '2',
#   '9',
#   '11',
#   '11',
#   '1',
#   '0',
#   '5',
#   '0',
#   '22',
#   '20.3',
#   '+23'],
#  ['9',
#   '2015-11-13',
#   '27-001',
#   'OKC',
#   '',
#   'PHI',
#   'W (+17)',
#   '1',
#   '34:47',
#   '8',
#   '22',
#   '.364',
#   '2',
#   '6',
#   '.333',
#   '3',
#   '4',
#   '.750',
#   '4',
#   '13',
#   '17',
#   '11',
#   '3',
#   '0',
#   '6',
#   '1',
#   '21',
#   '19.4',
#   '+16'],
#  ['10',
#   '2015-11-15',
#   '27-003',
#   'OKC',
#   '',
#   'BOS',
#   'L (-15)',
#   '1',
#   '32:37',
#   '5',
#   '20',
#   '.250',
#   '2',
#   '10',
#   '.200',
#   '15',
#   '17',
#   '.882',
#   '1',
#   '3',
#   '4',
#   '5',
#   '3',
#   '2',
#   '4',
#   '4',
#   '27',
#   '18.1',
#   '-7'],
#  ['11',
#   '2015-11-16',
#   '27-004',
#   'OKC',
#   '@',
#   'MEM',
#   'L (-8)',
#   '1',
#   '38:32',
#   '13',
#   '19',
#   '.684',
#   '5',
#   '8',
#   '.625',
#   '9',
#   '13',
#   '.692',
#   '1',
#   '3',
#   '4',
#   '14',
#   '3',
#   '0',
#   '8',
#   '1',
#   '40',
#   '36.3',
#   '+2'],
#  ['12',
#   '2015-11-18',
#   '27-006',
#   'OKC',
#   '',
#   'NOP',
#   'W (+7)',
#   '1',
#   '36:04',
#   '14',
#   '25',
#   '.560',
#   '0',
#   '3',
#   '.000',
#   '15',
#   '20',
#   '.750',
#   '3',
#   '6',
#   '9',
#   '8',
#   '1',
#   '1',
#   '4',
#   '1',
#   '43',
#   '35.9',
#   '-5'],
#  ['13',
#   '2015-11-20',
#   '27-008',
#   'OKC',
#   '',
#   'NYK',
#   'L (-3)',
#   '1',
#   '37:37',
#   '11',
#   '29',
#   '.379',
#   '2',
#   '10',
#   '.200',
#   '10',
#   '12',
#   '.833',
#   '3',
#   '4',
#   '7',
#   '7',
#   '4',
#   '1',
#   '3',
#   '4',
#   '34',
#   '25.6',
#   '+4'],
#  ['14',
#   '2015-11-22',
#   '27-010',
#   'OKC',
#   '',
#   'DAL',
#   'W (+3)',
#   '1',
#   '36:53',
#   '12',
#   '22',
#   '.545',
#   '2',
#   '5',
#   '.400',
#   '5',
#   '6',
#   '.833',
#   '0',
#   '5',
#   '5',
#   '11',
#   '5',
#   '1',
#   '7',
#   '1',
#   '31',
#   '27.5',
#   '+4'],
#  ['15',
#   '2015-11-23',
#   '27-011',
#   'OKC',
#   '@',
#   'UTA',
#   'W (+22)',
#   '1',
#   '27:18',
#   '5',
#   '10',
#   '.500',
#   '0',
#   '2',
#   '.000',
#   '10',
#   '10',
#   '1.000',
#   '2',
#   '5',
#   '7',
#   '9',
#   '1',
#   '0',
#   '4',
#   '3',
#   '20',
#   '20.0',
#   '+9'],
#  ['16',
#   '2015-11-25',
#   '27-013',
#   'OKC',
#   '',
#   'BRK',
#   'W (+11)',
#   '1',
#   '35:14',
#   '10',
#   '16',
#   '.625',
#   '0',
#   '3',
#   '.000',
#   '7',
#   '8',
#   '.875',
#   '1',
#   '5',
#   '6',
#   '13',
#   '5',
#   '0',
#   '3',
#   '1',
#   '27',
#   '32.3',
#   '+16'],
#  ['17',
#   '2015-11-27',
#   '27-015',
#   'OKC',
#   '',
#   'DET',
#   'W (+16)',
#   '1',
#   '28:37',
#   '5',
#   '14',
#   '.357',
#   '1',
#   '3',
#   '.333',
#   '3',
#   '5',
#   '.600',
#   '2',
#   '2',
#   '4',
#   '4',
#   '1',
#   '0',
#   '11',
#   '6',
#   '14',
#   '-2.2',
#   '+9'],
#  ['18',
#   '2015-11-30',
#   '27-018',
#   'OKC',
#   '@',
#   'ATL',
#   'L (-6)',
#   '1',
#   '35:57',
#   '11',
#   '24',
#   '.458',
#   '1',
#   '5',
#   '.200',
#   '11',
#   '11',
#   '1.000',
#   '2',
#   '9',
#   '11',
#   '7',
#   '2',
#   '0',
#   '6',
#   '3',
#   '34',
#   '25.4',
#   '-2'],
#  ['19',
#   '2015-12-03',
#   '27-021',
#   'OKC',
#   '@',
#   'MIA',
#   'L (-2)',
#   '1',
#   '34:27',
#   '8',
#   '18',
#   '.444',
#   '0',
#   '3',
#   '.000',
#   '9',
#   '9',
#   '1.000',
#   '1',
#   '4',
#   '5',
#   '6',
#   '1',
#   '0',
#   '7',
#   '1',
#   '25',
#   '15.3',
#   '+8'],
#  ['20',
#   '2015-12-06',
#   '27-024',
#   'OKC',
#   '',
#   'SAC',
#   'W (+3)',
#   '1',
#   '37:52',
#   '7',
#   '13',
#   '.538',
#   '1',
#   '3',
#   '.333',
#   '4',
#   '5',
#   '.800',
#   '0',
#   '11',
#   '11',
#   '10',
#   '3',
#   '0',
#   '3',
#   '2',
#   '19',
#   '21.8',
#   '+13'],
#  [],
#  ['21',
#   '2015-12-08',
#   '27-026',
#   'OKC',
#   '@',
#   'MEM',
#   'W (+37)',
#   '1',
#   '24:56',
#   '5',
#   '7',
#   '.714',
#   '1',
#   '2',
#   '.500',
#   '2',
#   '2',
#   '1.000',
#   '1',
#   '4',
#   '5',
#   '16',
#   '2',
#   '0',
#   '3',
#   '1',
#   '13',
#   '21.8',
#   '+26'],
#  ['22',
#   '2015-12-10',
#   '27-028',
#   'OKC',
#   '',
#   'ATL',
#   'W (+13)',
#   '1',
#   '38:28',
#   '8',
#   '17',
#   '.471',
#   '3',
#   '4',
#   '.750',
#   '4',
#   '6',
#   '.667',
#   '2',
#   '4',
#   '6',
#   '10',
#   '3',
#   '0',
#   '2',
#   '2',
#   '23',
#   '23.3',
#   '+15'],
#  ['23',
#   '2015-12-11',
#   '27-029',
#   'OKC',
#   '@',
#   'UTA',
#   'W (+4)',
#   '1',
#   '35:02',
#   '8',
#   '19',
#   '.421',
#   '2',
#   '4',
#   '.500',
#   '6',
#   '6',
#   '1.000',
#   '1',
#   '6',
#   '7',
#   '7',
#   '2',
#   '0',
#   '3',
#   '2',
#   '24',
#   '19.5',
#   '+8'],
#  ['24',
#   '2015-12-13',
#   '27-031',
#   'OKC',
#   '',
#   'UTA',
#   'W (+6)',
#   '1',
#   '40:22',
#   '9',
#   '25',
#   '.360',
#   '0',
#   '4',
#   '.000',
#   '7',
#   '9',
#   '.778',
#   '2',
#   '9',
#   '11',
#   '5',
#   '2',
#   '2',
#   '1',
#   '2',
#   '25',
#   '19.5',
#   '+19'],
#  ['25',
#   '2015-12-16',
#   '27-034',
#   'OKC',
#   '',
#   'POR',
#   'W (+16)',
#   '1',
#   '26:53',
#   '5',
#   '15',
#   '.333',
#   '0',
#   '3',
#   '.000',
#   '3',
#   '3',
#   '1.000',
#   '1',
#   '2',
#   '3',
#   '5',
#   '2',
#   '2',
#   '3',
#   '2',
#   '13',
#   '8.9',
#   '+12'],
#  ['26',
#   '2015-12-17',
#   '27-035',
#   'OKC',
#   '@',
#   'CLE',
#   'L (-4)',
#   '1',
#   '34:28',
#   '10',
#   '18',
#   '.556',
#   '1',
#   '3',
#   '.333',
#   '6',
#   '6',
#   '1.000',
#   '0',
#   '3',
#   '3',
#   '10',
#   '3',
#   '0',
#   '4',
#   '4',
#   '27',
#   '23.7',
#   '-4'],
#  ['27',
#   '2015-12-19',
#   '27-037',
#   'OKC',
#   '',
#   'LAL',
#   'W (+40)',
#   '1',
#   '27:43',
#   '5',
#   '11',
#   '.455',
#   '0',
#   '1',
#   '.000',
#   '3',
#   '6',
#   '.500',
#   '0',
#   '1',
#   '1',
#   '11',
#   '1',
#   '0',
#   '4',
#   '2',
#   '13',
#   '10.3',
#   '+18'],
#  ['28',
#   '2015-12-21',
#   '27-039',
#   'OKC',
#   '@',
#   'LAC',
#   'W (+1)',
#   '1',
#   '37:19',
#   '11',
#   '25',
#   '.440',
#   '2',
#   '5',
#   '.400',
#   '9',
#   '11',
#   '.818',
#   '1',
#   '4',
#   '5',
#   '7',
#   '3',
#   '0',
#   '1',
#   '4',
#   '33',
#   '26.3',
#   '+8'],
#  ['29',
#   '2015-12-23',
#   '27-041',
#   'OKC',
#   '@',
#   'LAL',
#   'W (+35)',
#   '1',
#   '29:33',
#   '10',
#   '19',
#   '.526',
#   '0',
#   '1',
#   '.000',
#   '3',
#   '5',
#   '.600',
#   '3',
#   '5',
#   '8',
#   '8',
#   '2',
#   '0',
#   '2',
#   '2',
#   '23',
#   '21.3',
#   '+33'],
#  ['30',
#   '2015-12-25',
#   '27-043',
#   'OKC',
#   '',
#   'CHI',
#   'L (-9)',
#   '1',
#   '39:57',
#   '9',
#   '23',
#   '.391',
#   '1',
#   '7',
#   '.143',
#   '7',
#   '13',
#   '.538',
#   '1',
#   '6',
#   '7',
#   '8',
#   '6',
#   '0',
#   '6',
#   '3',
#   '26',
#   '18.0',
#   '-5'],
#  ['31',
#   '2015-12-27',
#   '27-045',
#   'OKC',
#   '',
#   'DEN',
#   'W (+10)',
#   '1',
#   '38:06',
#   '11',
#   '18',
#   '.611',
#   '2',
#   '3',
#   '.667',
#   '6',
#   '6',
#   '1.000',
#   '1',
#   '8',
#   '9',
#   '12',
#   '1',
#   '0',
#   '4',
#   '0',
#   '30',
#   '30.3',
#   '+14'],
#  ['32',
#   '2015-12-29',
#   '27-047',
#   'OKC',
#   '',
#   'MIL',
#   'W (+8)',
#   '1',
#   '34:47',
#   '10',
#   '22',
#   '.455',
#   '0',
#   '2',
#   '.000',
#   '7',
#   '8',
#   '.875',
#   '1',
#   '6',
#   '7',
#   '7',
#   '5',
#   '0',
#   '3',
#   '1',
#   '27',
#   '24.2',
#   '+5'],
#  ['33',
#   '2015-12-31',
#   '27-049',
#   'OKC',
#   '',
#   'PHO',
#   'W (+4)',
#   '1',
#   '34:28',
#   '12',
#   '19',
#   '.632',
#   '1',
#   '3',
#   '.333',
#   '11',
#   '11',
#   '1.000',
#   '0',
#   '1',
#   '1',
#   '12',
#   '5',
#   '1',
#   '2',
#   '1',
#   '36',
#   '39.5',
#   '+11'],
#  ['34',
#   '2016-01-02',
#   '27-051',
#   'OKC',
#   '@',
#   'CHO',
#   'W (+19)',
#   '1',
#   '30:47',
#   '4',
#   '15',
#   '.267',
#   '1',
#   '3',
#   '.333',
#   '7',
#   '8',
#   '.875',
#   '1',
#   '5',
#   '6',
#   '7',
#   '1',
#   '0',
#   '2',
#   '2',
#   '16',
#   '12.0',
#   '+16'],
#  ['35',
#   '2016-01-04',
#   '27-053',
#   'OKC',
#   '',
#   'SAC',
#   'L (-12)',
#   '1',
#   '41:09',
#   '6',
#   '23',
#   '.261',
#   '2',
#   '9',
#   '.222',
#   '3',
#   '3',
#   '1.000',
#   '1',
#   '7',
#   '8',
#   '15',
#   '1',
#   '0',
#   '7',
#   '4',
#   '17',
#   '9.0',
#   '+5'],
#  ['36',
#   '2016-01-06',
#   '27-055',
#   'OKC',
#   '',
#   'MEM',
#   'W (+18)',
#   '1',
#   '29:55',
#   '7',
#   '17',
#   '.412',
#   '0',
#   '2',
#   '.000',
#   '6',
#   '6',
#   '1.000',
#   '2',
#   '5',
#   '7',
#   '7',
#   '2',
#   '0',
#   '3',
#   '3',
#   '20',
#   '16.5',
#   '+15'],
#  ['37',
#   '2016-01-08',
#   '27-057',
#   'OKC',
#   '@',
#   'LAL',
#   'W (+4)',
#   '1',
#   '34:34',
#   '11',
#   '24',
#   '.458',
#   '1',
#   '4',
#   '.250',
#   '13',
#   '16',
#   '.813',
#   '3',
#   '9',
#   '12',
#   '7',
#   '1',
#   '0',
#   '6',
#   '1',
#   '36',
#   '26.7',
#   '+1'],
#  ['38',
#   '2016-01-10',
#   '27-059',
#   'OKC',
#   '@',
#   'POR',
#   'L (-5)',
#   '1',
#   '38:13',
#   '7',
#   '19',
#   '.368',
#   '2',
#   '4',
#   '.500',
#   '9',
#   '11',
#   '.818',
#   '1',
#   '8',
#   '9',
#   '15',
#   '3',
#   '0',
#   '4',
#   '6',
#   '25',
#   '23.9',
#   '+3'],
#  ['39',
#   '2016-01-12',
#   '27-061',
#   'OKC',
#   '@',
#   'MIN',
#   'W (+5)',
#   '1',
#   '33:19',
#   '8',
#   '15',
#   '.533',
#   '2',
#   '4',
#   '.500',
#   '4',
#   '6',
#   '.667',
#   '1',
#   '6',
#   '7',
#   '11',
#   '3',
#   '0',
#   '7',
#   '3',
#   '22',
#   '18.9',
#   '+11'],
#  ['40',
#   '2016-01-13',
#   '27-062',
#   'OKC',
#   '',
#   'DAL',
#   'W (+19)',
#   '1',
#   '14:40',
#   '0',
#   '3',
#   '.000',
#   '0',
#   '0',
#   '',
#   '0',
#   '4',
#   '.000',
#   '1',
#   '6',
#   '7',
#   '8',
#   '2',
#   '0',
#   '1',
#   '0',
#   '0',
#   '5.4',
#   '+20'],
#  [],
#  ['41',
#   '2016-01-15',
#   '27-064',
#   'OKC',
#   '',
#   'MIN',
#   'W (+20)',
#   '1',
#   '27:12',
#   '6',
#   '10',
#   '.600',
#   '0',
#   '1',
#   '.000',
#   '0',
#   '0',
#   '',
#   '3',
#   '8',
#   '11',
#   '10',
#   '2',
#   '0',
#   '2',
#   '4',
#   '12',
#   '17.3',
#   '+21'],
#  ['42',
#   '2016-01-17',
#   '27-066',
#   'OKC',
#   '',
#   'MIA',
#   'W (+25)',
#   '1',
#   '33:23',
#   '5',
#   '16',
#   '.313',
#   '1',
#   '4',
#   '.250',
#   '2',
#   '2',
#   '1.000',
#   '3',
#   '7',
#   '10',
#   '15',
#   '2',
#   '0',
#   '3',
#   '2',
#   '13',
#   '16.7',
#   '+15'],
#  ['43',
#   '2016-01-19',
#   '27-068',
#   'OKC',
#   '@',
#   'DEN',
#   'W (+6)',
#   '1',
#   '38:45',
#   '10',
#   '22',
#   '.455',
#   '1',
#   '6',
#   '.167',
#   '6',
#   '9',
#   '.667',
#   '4',
#   '1',
#   '5',
#   '12',
#   '3',
#   '0',
#   '4',
#   '5',
#   '27',
#   '22.9',
#   '+5'],
#  ['44',
#   '2016-01-20',
#   '27-069',
#   'OKC',
#   '',
#   'CHO',
#   'W (+14)',
#   '1',
#   '27:20',
#   '5',
#   '14',
#   '.357',
#   '0',
#   '3',
#   '.000',
#   '6',
#   '7',
#   '.857',
#   '1',
#   '7',
#   '8',
#   '15',
#   '5',
#   '0',
#   '5',
#   '2',
#   '16',
#   '20.3',
#   '+18'],
#  ['45',
#   '2016-01-22',
#   '27-071',
#   'OKC',
#   '@',
#   'DAL',
#   'W (+3)',
#   '1',
#   '34:36',
#   '8',
#   '19',
#   '.421',
#   '0',
#   '4',
#   '.000',
#   '0',
#   '0',
#   '',
#   '3',
#   '5',
#   '8',
#   '7',
#   '2',
#   '1',
#   '4',
#   '4',
#   '16',
#   '11.5',
#   '-9'],
#  ['46',
#   '2016-01-24',
#   '27-073',
#   'OKC',
#   '@',
#   'BRK',
#   'L (-10)',
#   '1',
#   '39:41',
#   '12',
#   '27',
#   '.444',
#   '1',
#   '4',
#   '.250',
#   '2',
#   '5',
#   '.400',
#   '2',
#   '9',
#   '11',
#   '7',
#   '1',
#   '0',
#   '3',
#   '1',
#   '27',
#   '18.3',
#   '-15'],
#  ['47',
#   '2016-01-26',
#   '27-075',
#   'OKC',
#   '@',
#   'NYK',
#   'W (+6)',
#   '1',
#   '44:16',
#   '13',
#   '24',
#   '.542',
#   '0',
#   '2',
#   '.000',
#   '4',
#   '5',
#   '.800',
#   '2',
#   '6',
#   '8',
#   '10',
#   '3',
#   '0',
#   '5',
#   '3',
#   '30',
#   '25.0',
#   '+18'],
#  ['48',
#   '2016-01-27',
#   '27-076',
#   'OKC',
#   '@',
#   'MIN',
#   'W (+3)',
#   '1',
#   '36:40',
#   '7',
#   '13',
#   '.538',
#   '3',
#   '4',
#   '.750',
#   '7',
#   '7',
#   '1.000',
#   '2',
#   '6',
#   '8',
#   '15',
#   '0',
#   '0',
#   '4',
#   '3',
#   '24',
#   '26.2',
#   '+1'],
#  ['49',
#   '2016-01-29',
#   '27-078',
#   'OKC',
#   '',
#   'HOU',
#   'W (+8)',
#   '1',
#   '37:07',
#   '9',
#   '21',
#   '.429',
#   '1',
#   '2',
#   '.500',
#   '7',
#   '10',
#   '.700',
#   '1',
#   '9',
#   '10',
#   '14',
#   '1',
#   '1',
#   '8',
#   '3',
#   '26',
#   '19.4',
#   '+6'],
#  ['50',
#   '2016-02-01',
#   '27-081',
#   'OKC',
#   '',
#   'WAS',
#   'W (+16)',
#   '1',
#   '36:08',
#   '8',
#   '13',
#   '.615',
#   '0',
#   '3',
#   '.000',
#   '1',
#   '1',
#   '1.000',
#   '1',
#   '12',
#   '13',
#   '11',
#   '1',
#   '0',
#   '5',
#   '2',
#   '17',
#   '18.3',
#   '+14'],
#  ['51',
#   '2016-02-03',
#   '27-083',
#   'OKC',
#   '',
#   'ORL',
#   'W (+3)',
#   '1',
#   '37:41',
#   '10',
#   '18',
#   '.556',
#   '0',
#   '1',
#   '.000',
#   '4',
#   '4',
#   '1.000',
#   '7',
#   '12',
#   '19',
#   '14',
#   '2',
#   '0',
#   '2',
#   '1',
#   '24',
#   '33.3',
#   '+10'],
#  ['52',
#   '2016-02-06',
#   '27-086',
#   'OKC',
#   '@',
#   'GSW',
#   'L (-8)',
#   '1',
#   '37:24',
#   '8',
#   '22',
#   '.364',
#   '2',
#   '4',
#   '.500',
#   '9',
#   '9',
#   '1.000',
#   '2',
#   '1',
#   '3',
#   '12',
#   '3',
#   '0',
#   '3',
#   '4',
#   '27',
#   '23.3',
#   '-5'],
#  ['53',
#   '2016-02-08',
#   '27-088',
#   'OKC',
#   '@',
#   'PHO',
#   'W (+16)',
#   '1',
#   '36:14',
#   '8',
#   '19',
#   '.421',
#   '2',
#   '5',
#   '.400',
#   '11',
#   '12',
#   '.917',
#   '3',
#   '5',
#   '8',
#   '8',
#   '2',
#   '0',
#   '6',
#   '4',
#   '29',
#   '22.1',
#   '+1'],
#  ['54',
#   '2016-02-11',
#   '27-091',
#   'OKC',
#   '',
#   'NOP',
#   'W (+26)',
#   '1',
#   '28:25',
#   '8',
#   '14',
#   '.571',
#   '2',
#   '5',
#   '.400',
#   '5',
#   '6',
#   '.833',
#   '1',
#   '8',
#   '9',
#   '10',
#   '0',
#   '0',
#   '2',
#   '2',
#   '23',
#   '23.3',
#   '+19'],
#  ['55',
#   '2016-02-19',
#   '27-099',
#   'OKC',
#   '',
#   'IND',
#   'L (-3)',
#   '1',
#   '37:09',
#   '10',
#   '17',
#   '.588',
#   '1',
#   '4',
#   '.250',
#   '2',
#   '2',
#   '1.000',
#   '0',
#   '3',
#   '3',
#   '18',
#   '2',
#   '1',
#   '2',
#   '2',
#   '23',
#   '28.5',
#   '-4'],
#  ['56',
#   '2016-02-21',
#   '27-101',
#   'OKC',
#   '',
#   'CLE',
#   'L (-23)',
#   '1',
#   '33:04',
#   '7',
#   '15',
#   '.467',
#   '1',
#   '3',
#   '.333',
#   '5',
#   '6',
#   '.833',
#   '3',
#   '6',
#   '9',
#   '11',
#   '1',
#   '0',
#   '1',
#   '3',
#   '20',
#   '22.3',
#   '-16'],
#  ['57',
#   '2016-02-24',
#   '27-104',
#   'OKC',
#   '@',
#   'DAL',
#   'W (+13)',
#   '1',
#   '36:09',
#   '8',
#   '17',
#   '.471',
#   '2',
#   '5',
#   '.400',
#   '6',
#   '6',
#   '1.000',
#   '2',
#   '5',
#   '7',
#   '13',
#   '0',
#   '0',
#   '2',
#   '4',
#   '24',
#   '23.7',
#   '+9'],
#  ['58',
#   '2016-02-25',
#   '27-105',
#   'OKC',
#   '@',
#   'NOP',
#   'L (-4)',
#   '1',
#   '37:37',
#   '15',
#   '25',
#   '.600',
#   '3',
#   '5',
#   '.600',
#   '11',
#   '14',
#   '.786',
#   '2',
#   '2',
#   '4',
#   '9',
#   '0',
#   '0',
#   '2',
#   '3',
#   '44',
#   '36.4',
#   '+6'],
#  ['59',
#   '2016-02-27',
#   '27-107',
#   'OKC',
#   '',
#   'GSW',
#   'L (-3)',
#   '1',
#   '42:11',
#   '10',
#   '29',
#   '.345',
#   '0',
#   '6',
#   '.000',
#   '6',
#   '8',
#   '.750',
#   '3',
#   '4',
#   '7',
#   '13',
#   '2',
#   '0',
#   '7',
#   '4',
#   '26',
#   '14.7',
#   '-5'],
#  ['60',
#   '2016-02-29',
#   '27-109',
#   'OKC',
#   '@',
#   'SAC',
#   'W (+15)',
#   '1',
#   '34:35',
#   '6',
#   '8',
#   '.750',
#   '2',
#   '3',
#   '.667',
#   '6',
#   '7',
#   '.857',
#   '2',
#   '11',
#   '13',
#   '15',
#   '3',
#   '0',
#   '7',
#   '2',
#   '20',
#   '26.8',
#   '+2'],
#  [],
#  ['61',
#   '2016-03-02',
#   '27-111',
#   'OKC',
#   '@',
#   'LAC',
#   'L (-5)',
#   '1',
#   '36:51',
#   '8',
#   '21',
#   '.381',
#   '2',
#   '7',
#   '.286',
#   '6',
#   '6',
#   '1.000',
#   '0',
#   '6',
#   '6',
#   '12',
#   '1',
#   '0',
#   '5',
#   '4',
#   '24',
#   '17.1',
#   '-7'],
#  ['62',
#   '2016-03-03',
#   '27-112',
#   'OKC',
#   '@',
#   'GSW',
#   'L (-15)',
#   '1',
#   '36:03',
#   '8',
#   '24',
#   '.333',
#   '1',
#   '8',
#   '.125',
#   '5',
#   '7',
#   '.714',
#   '1',
#   '5',
#   '6',
#   '7',
#   '0',
#   '1',
#   '2',
#   '4',
#   '22',
#   '11.8',
#   '-6'],
#  ['63',
#   '2016-03-06',
#   '27-115',
#   'OKC',
#   '@',
#   'MIL',
#   'W (+8)',
#   '1',
#   '38:50',
#   '3',
#   '7',
#   '.429',
#   '1',
#   '3',
#   '.333',
#   '8',
#   '11',
#   '.727',
#   '2',
#   '8',
#   '10',
#   '11',
#   '1',
#   '1',
#   '7',
#   '4',
#   '15',
#   '14.7',
#   '+15'],
#  ['64',
#   '2016-03-09',
#   '27-118',
#   'OKC',
#   '',
#   'LAC',
#   'W (+12)',
#   '1',
#   '37:02',
#   '9',
#   '15',
#   '.600',
#   '0',
#   '2',
#   '.000',
#   '7',
#   '7',
#   '1.000',
#   '2',
#   '9',
#   '11',
#   '19',
#   '2',
#   '1',
#   '7',
#   '2',
#   '25',
#   '30.4',
#   '0'],
#  ['65',
#   '2016-03-11',
#   '27-120',
#   'OKC',
#   '',
#   'MIN',
#   'L (-3)',
#   '1',
#   '37:10',
#   '8',
#   '19',
#   '.421',
#   '3',
#   '6',
#   '.500',
#   '7',
#   '8',
#   '.875',
#   '0',
#   '4',
#   '4',
#   '8',
#   '0',
#   '0',
#   '5',
#   '4',
#   '26',
#   '15.7',
#   '-10'],
#  ['66',
#   '2016-03-12',
#   '27-121',
#   'OKC',
#   '@',
#   'SAS',
#   'L (-8)',
#   '1',
#   '38:14',
#   '5',
#   '16',
#   '.313',
#   '1',
#   '4',
#   '.250',
#   '8',
#   '10',
#   '.800',
#   '3',
#   '3',
#   '6',
#   '7',
#   '2',
#   '0',
#   '9',
#   '3',
#   '19',
#   '8.7',
#   '-1'],
#  ['67',
#   '2016-03-14',
#   '27-123',
#   'OKC',
#   '',
#   'POR',
#   'W (+34)',
#   '1',
#   '28:27',
#   '7',
#   '11',
#   '.636',
#   '0',
#   '0',
#   '',
#   '3',
#   '6',
#   '.500',
#   '2',
#   '8',
#   '10',
#   '16',
#   '2',
#   '1',
#   '0',
#   '2',
#   '17',
#   '27.8',
#   '+16'],
#  ['68',
#   '2016-03-16',
#   '27-125',
#   'OKC',
#   '@',
#   'BOS',
#   'W (+21)',
#   '1',
#   '26:09',
#   '8',
#   '16',
#   '.500',
#   '4',
#   '7',
#   '.571',
#   '4',
#   '8',
#   '.500',
#   '1',
#   '4',
#   '5',
#   '5',
#   '3',
#   '0',
#   '2',
#   '1',
#   '24',
#   '20.4',
#   '+15'],
#  ['69',
#   '2016-03-18',
#   '27-127',
#   'OKC',
#   '@',
#   'PHI',
#   'W (+14)',
#   '1',
#   '32:26',
#   '8',
#   '20',
#   '.400',
#   '2',
#   '5',
#   '.400',
#   '2',
#   '4',
#   '.500',
#   '3',
#   '12',
#   '15',
#   '10',
#   '1',
#   '2',
#   '5',
#   '2',
#   '20',
#   '17.7',
#   '+27'],
#  ['70',
#   '2016-03-19',
#   '27-128',
#   'OKC',
#   '@',
#   'IND',
#   'W (+4)',
#   '1',
#   '35:56',
#   '4',
#   '17',
#   '.235',
#   '3',
#   '9',
#   '.333',
#   '3',
#   '4',
#   '.750',
#   '3',
#   '8',
#   '11',
#   '14',
#   '1',
#   '0',
#   '7',
#   '4',
#   '14',
#   '10.0',
#   '-2'],
#  ['71',
#   '2016-03-22',
#   '27-131',
#   'OKC',
#   '',
#   'HOU',
#   'W (+4)',
#   '1',
#   '36:52',
#   '7',
#   '18',
#   '.389',
#   '0',
#   '7',
#   '.000',
#   '7',
#   '8',
#   '.875',
#   '3',
#   '9',
#   '12',
#   '15',
#   '1',
#   '0',
#   '4',
#   '1',
#   '21',
#   '22.7',
#   '-5'],
#  ['72',
#   '2016-03-24',
#   '27-133',
#   'OKC',
#   '',
#   'UTA',
#   'W (+22)',
#   '1',
#   '27:15',
#   '6',
#   '15',
#   '.400',
#   '1',
#   '3',
#   '.333',
#   '2',
#   '3',
#   '.667',
#   '1',
#   '6',
#   '7',
#   '9',
#   '3',
#   '0',
#   '2',
#   '1',
#   '15',
#   '15.9',
#   '+16'],
#  ['73',
#   '2016-03-26',
#   '27-135',
#   'OKC',
#   '',
#   'SAS',
#   'W (+19)',
#   '1',
#   '34:25',
#   '10',
#   '18',
#   '.556',
#   '0',
#   '2',
#   '.000',
#   '9',
#   '9',
#   '1.000',
#   '2',
#   '4',
#   '6',
#   '8',
#   '1',
#   '0',
#   '2',
#   '1',
#   '29',
#   '27.2',
#   '+30'],
#  ['74',
#   '2016-03-28',
#   '27-137',
#   'OKC',
#   '@',
#   'TOR',
#   'W (+19)',
#   '1',
#   '34:06',
#   '10',
#   '16',
#   '.625',
#   '1',
#   '3',
#   '.333',
#   '5',
#   '8',
#   '.625',
#   '3',
#   '7',
#   '10',
#   '12',
#   '1',
#   '0',
#   '3',
#   '1',
#   '26',
#   '27.8',
#   '+35'],
#  ['75',
#   '2016-03-29',
#   '27-138',
#   'OKC',
#   '@',
#   'DET',
#   'L (-6)',
#   '1',
#   '34:42',
#   '8',
#   '28',
#   '.286',
#   '2',
#   '8',
#   '.250',
#   '6',
#   '9',
#   '.667',
#   '2',
#   '2',
#   '4',
#   '6',
#   '1',
#   '0',
#   '3',
#   '4',
#   '24',
#   '9.0',
#   '-20'],
#  ['76',
#   '2016-03-31',
#   '27-140',
#   'OKC',
#   '',
#   'LAC',
#   'W (+2)',
#   '1',
#   '35:49',
#   '8',
#   '18',
#   '.444',
#   '3',
#   '7',
#   '.429',
#   '7',
#   '7',
#   '1.000',
#   '1',
#   '7',
#   '8',
#   '11',
#   '4',
#   '0',
#   '5',
#   '0',
#   '26',
#   '26.1',
#   '-4'],
#  ['77',
#   '2016-04-03',
#   '27-143',
#   'OKC',
#   '@',
#   'HOU',
#   'L (-8)',
#   '1',
#   '37:24',
#   '8',
#   '15',
#   '.533',
#   '1',
#   '4',
#   '.250',
#   '6',
#   '7',
#   '.857',
#   '3',
#   '10',
#   '13',
#   '9',
#   '2',
#   '0',
#   '8',
#   '3',
#   '23',
#   '19.5',
#   '-8'],
#  ['78',
#   '2016-04-05',
#   '27-145',
#   'OKC',
#   '@',
#   'DEN',
#   'W (+22)',
#   '1',
#   '26:41',
#   '4',
#   '9',
#   '.444',
#   '2',
#   '4',
#   '.500',
#   '3',
#   '5',
#   '.600',
#   '3',
#   '11',
#   '14',
#   '12',
#   '2',
#   '0',
#   '5',
#   '1',
#   '13',
#   '17.9',
#   '+26'],
#  ['', '2016-04-06', '27-146', 'OKC', '@', 'POR', 'L (-5)', 'Did Not Play'],
#  ['79',
#   '2016-04-09',
#   '27-149',
#   'OKC',
#   '@',
#   'SAC',
#   'L (-2)',
#   '1',
#   '33:42',
#   '7',
#   '15',
#   '.467',
#   '1',
#   '5',
#   '.200',
#   '9',
#   '10',
#   '.900',
#   '1',
#   '4',
#   '5',
#   '10',
#   '1',
#   '0',
#   '8',
#   '5',
#   '24',
#   '15.8',
#   '+3'],
#  [],
#  ['80',
#   '2016-04-11',
#   '27-151',
#   'OKC',
#   '',
#   'LAL',
#   'W (+33)',
#   '1',
#   '27:39',
#   '5',
#   '13',
#   '.385',
#   '0',
#   '5',
#   '.000',
#   '3',
#   '5',
#   '.600',
#   '0',
#   '10',
#   '10',
#   '14',
#   '1',
#   '0',
#   '3',
#   '2',
#   '13',
#   '15.1',
#   '+27'],
#  ['', '2016-04-12', '27-152', 'OKC', '@', 'SAS', 'L (-4)', 'Not With Team']]

# %%
pd.DataFrame(season_stats,columns=headers)
# Out:
#        G        Date     Age    Tm         Opp                      GS     MP  \
# 0      1  2015-10-28  26-350   OKC         SAS   W (+6)              1  36:59
# 1      2  2015-10-30  26-352   OKC     @   ORL   W (+3)              1  47:35
# 2      3  2015-11-01  26-354   OKC         DEN  W (+24)              1  25:26
# 3      4  2015-11-02  26-355   OKC     @   HOU   L (-5)              1  31:57
# 4      5  2015-11-04  26-357   OKC         TOR   L (-5)              1  35:20
# 5      6  2015-11-05  26-358   OKC     @   CHI   L (-6)              1  38:34
# 6      7  2015-11-08  26-361   OKC         PHO  W (+21)              1  33:58
# 7      8  2015-11-10  26-363   OKC     @   WAS  W (+24)              1  27:46
# 8      9  2015-11-13  27-001   OKC         PHI  W (+17)              1  34:47
# 9     10  2015-11-15  27-003   OKC         BOS  L (-15)              1  32:37
# 10    11  2015-11-16  27-004   OKC     @   MEM   L (-8)              1  38:32
# 11    12  2015-11-18  27-006   OKC         NOP   W (+7)              1  36:04
# 12    13  2015-11-20  27-008   OKC         NYK   L (-3)              1  37:37
# 13    14  2015-11-22  27-010   OKC         DAL   W (+3)              1  36:53
# 14    15  2015-11-23  27-011   OKC     @   UTA  W (+22)              1  27:18
# 15    16  2015-11-25  27-013   OKC         BRK  W (+11)              1  35:14
# 16    17  2015-11-27  27-015   OKC         DET  W (+16)              1  28:37
# 17    18  2015-11-30  27-018   OKC     @   ATL   L (-6)              1  35:57
# 18    19  2015-12-03  27-021   OKC     @   MIA   L (-2)              1  34:27
# 19    20  2015-12-06  27-024   OKC         SAC   W (+3)              1  37:52
# 20  None        None    None  None  None  None     None           None   None
# 21    21  2015-12-08  27-026   OKC     @   MEM  W (+37)              1  24:56
# 22    22  2015-12-10  27-028   OKC         ATL  W (+13)              1  38:28
# 23    23  2015-12-11  27-029   OKC     @   UTA   W (+4)              1  35:02
# 24    24  2015-12-13  27-031   OKC         UTA   W (+6)              1  40:22
# 25    25  2015-12-16  27-034   OKC         POR  W (+16)              1  26:53
# 26    26  2015-12-17  27-035   OKC     @   CLE   L (-4)              1  34:28
# 27    27  2015-12-19  27-037   OKC         LAL  W (+40)              1  27:43
# 28    28  2015-12-21  27-039   OKC     @   LAC   W (+1)              1  37:19
# 29    29  2015-12-23  27-041   OKC     @   LAL  W (+35)              1  29:33
# ..   ...         ...     ...   ...   ...   ...      ...            ...    ...
# 56    55  2016-02-19  27-099   OKC         IND   L (-3)              1  37:09
# 57    56  2016-02-21  27-101   OKC         CLE  L (-23)              1  33:04
# 58    57  2016-02-24  27-104   OKC     @   DAL  W (+13)              1  36:09
# 59    58  2016-02-25  27-105   OKC     @   NOP   L (-4)              1  37:37
# 60    59  2016-02-27  27-107   OKC         GSW   L (-3)              1  42:11
# 61    60  2016-02-29  27-109   OKC     @   SAC  W (+15)              1  34:35
# 62  None        None    None  None  None  None     None           None   None
# 63    61  2016-03-02  27-111   OKC     @   LAC   L (-5)              1  36:51
# 64    62  2016-03-03  27-112   OKC     @   GSW  L (-15)              1  36:03
# 65    63  2016-03-06  27-115   OKC     @   MIL   W (+8)              1  38:50
# 66    64  2016-03-09  27-118   OKC         LAC  W (+12)              1  37:02
# 67    65  2016-03-11  27-120   OKC         MIN   L (-3)              1  37:10
# 68    66  2016-03-12  27-121   OKC     @   SAS   L (-8)              1  38:14
# 69    67  2016-03-14  27-123   OKC         POR  W (+34)              1  28:27
# 70    68  2016-03-16  27-125   OKC     @   BOS  W (+21)              1  26:09
# 71    69  2016-03-18  27-127   OKC     @   PHI  W (+14)              1  32:26
# 72    70  2016-03-19  27-128   OKC     @   IND   W (+4)              1  35:56
# 73    71  2016-03-22  27-131   OKC         HOU   W (+4)              1  36:52
# 74    72  2016-03-24  27-133   OKC         UTA  W (+22)              1  27:15
# 75    73  2016-03-26  27-135   OKC         SAS  W (+19)              1  34:25
# 76    74  2016-03-28  27-137   OKC     @   TOR  W (+19)              1  34:06
# 77    75  2016-03-29  27-138   OKC     @   DET   L (-6)              1  34:42
# 78    76  2016-03-31  27-140   OKC         LAC   W (+2)              1  35:49
# 79    77  2016-04-03  27-143   OKC     @   HOU   L (-8)              1  37:24
# 80    78  2016-04-05  27-145   OKC     @   DEN  W (+22)              1  26:41
# 81        2016-04-06  27-146   OKC     @   POR   L (-5)   Did Not Play   None
# 82    79  2016-04-09  27-149   OKC     @   SAC   L (-2)              1  33:42
# 83  None        None    None  None  None  None     None           None   None
# 84    80  2016-04-11  27-151   OKC         LAL  W (+33)              1  27:39
# 85        2016-04-12  27-152   OKC     @   SAS   L (-4)  Not With Team   None
#
#       FG  ...   DRB   TRB   AST   STL   BLK   TOV    PF   PTS  GmSc   +/-
# 0     12  ...     1     2    10     2     0     5     3    33  25.1    +7
# 1     17  ...     6    11     8     1     1     6     3    48  33.8    +2
# 2      7  ...     7     9     8     3     0     4     0    15  16.8   +22
# 3     10  ...     6     8    11     2     0     7     5    25  21.7    +4
# 4      8  ...     5     5    16     2     0     8     4    22  15.2    +3
# 5      7  ...     6     8    10     1     0     2     2    20  18.6    +8
# 6      9  ...     2     6    13     4     0     2     3    21  23.5   +26
# 7      7  ...     9    11    11     1     0     5     0    22  20.3   +23
# 8      8  ...    13    17    11     3     0     6     1    21  19.4   +16
# 9      5  ...     3     4     5     3     2     4     4    27  18.1    -7
# 10    13  ...     3     4    14     3     0     8     1    40  36.3    +2
# 11    14  ...     6     9     8     1     1     4     1    43  35.9    -5
# 12    11  ...     4     7     7     4     1     3     4    34  25.6    +4
# 13    12  ...     5     5    11     5     1     7     1    31  27.5    +4
# 14     5  ...     5     7     9     1     0     4     3    20  20.0    +9
# 15    10  ...     5     6    13     5     0     3     1    27  32.3   +16
# 16     5  ...     2     4     4     1     0    11     6    14  -2.2    +9
# 17    11  ...     9    11     7     2     0     6     3    34  25.4    -2
# 18     8  ...     4     5     6     1     0     7     1    25  15.3    +8
# 19     7  ...    11    11    10     3     0     3     2    19  21.8   +13
# 20  None  ...  None  None  None  None  None  None  None  None  None  None
# 21     5  ...     4     5    16     2     0     3     1    13  21.8   +26
# 22     8  ...     4     6    10     3     0     2     2    23  23.3   +15
# 23     8  ...     6     7     7     2     0     3     2    24  19.5    +8
# 24     9  ...     9    11     5     2     2     1     2    25  19.5   +19
# 25     5  ...     2     3     5     2     2     3     2    13   8.9   +12
# 26    10  ...     3     3    10     3     0     4     4    27  23.7    -4
# 27     5  ...     1     1    11     1     0     4     2    13  10.3   +18
# 28    11  ...     4     5     7     3     0     1     4    33  26.3    +8
# 29    10  ...     5     8     8     2     0     2     2    23  21.3   +33
# ..   ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 56    10  ...     3     3    18     2     1     2     2    23  28.5    -4
# 57     7  ...     6     9    11     1     0     1     3    20  22.3   -16
# 58     8  ...     5     7    13     0     0     2     4    24  23.7    +9
# 59    15  ...     2     4     9     0     0     2     3    44  36.4    +6
# 60    10  ...     4     7    13     2     0     7     4    26  14.7    -5
# 61     6  ...    11    13    15     3     0     7     2    20  26.8    +2
# 62  None  ...  None  None  None  None  None  None  None  None  None  None
# 63     8  ...     6     6    12     1     0     5     4    24  17.1    -7
# 64     8  ...     5     6     7     0     1     2     4    22  11.8    -6
# 65     3  ...     8    10    11     1     1     7     4    15  14.7   +15
# 66     9  ...     9    11    19     2     1     7     2    25  30.4     0
# 67     8  ...     4     4     8     0     0     5     4    26  15.7   -10
# 68     5  ...     3     6     7     2     0     9     3    19   8.7    -1
# 69     7  ...     8    10    16     2     1     0     2    17  27.8   +16
# 70     8  ...     4     5     5     3     0     2     1    24  20.4   +15
# 71     8  ...    12    15    10     1     2     5     2    20  17.7   +27
# 72     4  ...     8    11    14     1     0     7     4    14  10.0    -2
# 73     7  ...     9    12    15     1     0     4     1    21  22.7    -5
# 74     6  ...     6     7     9     3     0     2     1    15  15.9   +16
# 75    10  ...     4     6     8     1     0     2     1    29  27.2   +30
# 76    10  ...     7    10    12     1     0     3     1    26  27.8   +35
# 77     8  ...     2     4     6     1     0     3     4    24   9.0   -20
# 78     8  ...     7     8    11     4     0     5     0    26  26.1    -4
# 79     8  ...    10    13     9     2     0     8     3    23  19.5    -8
# 80     4  ...    11    14    12     2     0     5     1    13  17.9   +26
# 81  None  ...  None  None  None  None  None  None  None  None  None  None
# 82     7  ...     4     5    10     1     0     8     5    24  15.8    +3
# 83  None  ...  None  None  None  None  None  None  None  None  None  None
# 84     5  ...    10    10    14     1     0     3     2    13  15.1   +27
# 85  None  ...  None  None  None  None  None  None  None  None  None  None
#
# [86 rows x 29 columns]
