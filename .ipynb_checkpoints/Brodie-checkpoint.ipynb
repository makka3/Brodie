# %%
import pandas as pd
import numpy as np
import time
import requests
from bs4 import BeautifulSoup
import re

# %%
westbrook = requests.get("https://www.basketball-reference.com/players/w/westbru01/gamelog/2016")

# %%
westbrook.status_code
# Out:
# 200

# %%
westbrook.headers
# Out:
# {'Date': 'Fri, 01 Nov 2019 15:01:36 GMT', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Keep-Alive': 'timeout=15', 'Vary': 'Accept-Encoding', 'SR-MISS-MEMD-KEY': '/players/w/westbru01/gamelog/2016', 'X-Accel-Expires': '28800', 'Source': 'back-1-bbr', 'X-cache-key-basic': 'www.basketball-reference.com/players/w/westbru01/gamelog/2016', 'X-Cache-Status': 'HIT', 'Content-Encoding': 'gzip'}

# %%
westbrook.text

# %%
russ = BeautifulSoup(westbrook.text,'lxml')

# %%
russ

# %%
games = russ.find("div", {"id": "all_pgl_basic"}).find_all('tr')

# %%
games

# %%
headers_list = []

for i in games[0].find_all('th'):
    entry = i.getText()
    headers_list.append(entry)

# %%
headers_list
# Out:
# ['Rk',
#  'G',
#  'Date',
#  'Age',
#  'Tm',
#  '\xa0',
#  'Opp',
#  '\xa0',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS',
#  'GmSc',
#  '+/-']

# %%
headers_list[7] = "WL"

# %%
headers_list[5] = "HA"

# %%
headers_list
# Out:
# ['Rk',
#  'G',
#  'Date',
#  'Age',
#  'Tm',
#  'HA',
#  'Opp',
#  'WL',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS',
#  'GmSc',
#  '+/-']

# %%
stats = []

for i in games[74].find_all('td'):
    stats.append(i.getText())

# %%
stats
# Out:
# ['71',
#  '2016-03-22',
#  '27-131',
#  'OKC',
#  '',
#  'HOU',
#  'W (+4)',
#  '1',
#  '36:52',
#  '7',
#  '18',
#  '.389',
#  '0',
#  '7',
#  '.000',
#  '7',
#  '8',
#  '.875',
#  '3',
#  '9',
#  '12',
#  '15',
#  '1',
#  '0',
#  '4',
#  '1',
#  '21',
#  '22.7',
#  '-5']

# %%
len(games)
# Out:
# 87

# %%
def sea_stats(year):
    player_year = requests.get("https://www.basketball-reference.com/players/w/westbru01/gamelog/" + year)
    player_games = BeautifulSoup(player_year.text,'lxml')
    games = player_games.find("div", {"id": "all_pgl_basic"}).find_all('tr')
    
    headers = []
    season_stats = []

    for w in games[0].find_all('th'):
        entry = w.getText()
        headers.append(entry)

    headers[5] = "HA"
    headers[7] = "WL"
    
    headers = headers[1:] # To get headers
    
    for i in range(1,len(games)):
        game_stats = []
        for j in games[i].find_all('td'):
            game_stats.append(j.getText())
        season_stats.append(game_stats)
    
    season_stat = [x for x in season_stats if x] # To remove empty rows
    
    return pd.DataFrame(season_stat,columns=headers)

# %%
active_years = []
for i in range(2016,2021):
    active_years.append(str(i))

# %%
active_years
# Out:
# ['2016', '2017', '2018', '2019', '2020']

# %%
list_of_seasons = []

for i in active_years:
    list_of_seasons.append(sea_stats(i))

# %%
result = pd.concat(list_of_seasons)

# %%
result.insert(1,"Name",)

# %%
result
# Out:
#      G  Name        Date     Age   Tm HA  Opp       WL             GS     MP  \
# 0    1  Russ  2008-10-29  19-352  OKC     MIL  L (-11)              0  21:56
# 1    2  Russ  2008-11-01  19-355  OKC  @  HOU  L (-12)              0  18:32
# 64  57  Russ  2019-03-07  30-115  OKC  @  POR   W (+8)              1  40:04
# 65  58  Russ  2019-03-08  30-116  OKC  @  LAC   L (-8)              1  31:58
# 66  59  Russ  2019-03-11  30-119  OKC  @  UTA   W (+9)              1  37:20
# 67  60  Russ  2019-03-13  30-121  OKC     BRK  W (+12)              1  35:49
# 68  61  Russ  2019-03-14  30-122  OKC  @  IND   L (-2)              1  38:20
# 69  62  Russ  2019-03-16  30-124  OKC     GSW  L (-22)              1  31:56
# 70      Russ  2019-03-18  30-126  OKC     MIA   L (-9)  Not With Team   None
# 71  63  Russ  2019-03-20  30-128  OKC     TOR   L (-9)              1  43:55
# 72  64  Russ  2019-03-22  30-130  OKC  @  TOR   W (+7)              1  36:46
# 73  65  Russ  2019-03-25  30-133  OKC  @  MEM  L (-12)              1  36:45
# 74  66  Russ  2019-03-27  30-135  OKC     IND   W (+8)              1  36:51
# 75  67  Russ  2019-03-29  30-137  OKC     DEN  L (-10)              1  35:39
# 76  68  Russ  2019-03-31  30-139  OKC     DAL   L (-3)              1  37:39
# 77  69  Russ  2019-04-02  30-141  OKC     LAL  W (+16)              1  36:48
# 78  70  Russ  2019-04-05  30-144  OKC     DET  W (+13)              1  35:12
# 79  71  Russ  2019-04-07  30-146  OKC  @  MIN   W (+6)              1  38:11
# 80  72  Russ  2019-04-09  30-148  OKC     HOU   W (+1)              1  37:04
# 81  73  Russ  2019-04-10  30-149  OKC  @  MIL  W (+11)              1  36:28
# 0    1  Russ  2019-10-24  30-346  HOU     MIL   L (-6)              1  32:52
# 1    2  Russ  2019-10-26  30-348  HOU     NOP   W (+3)              1  33:35
# 2    3  Russ  2019-10-28  30-350  HOU     OKC   W (+4)              1  35:29
# 3    4  Russ  2019-10-30  30-352  HOU  @  WAS   W (+1)              1  34:41
#
#     ...   DRB   TRB   AST   STL   BLK   TOV    PF   PTS  GmSc   +/-
# 0   ...     0     4     4     0     1     2     2    13  11.0    +5
# 1   ...     2     2     3     1     0     2     2     6   2.8   -19
# 2   ...     0     1     2     2     0     3     1    14   7.6    +7
# 3   ...     2     5     1     1     0     2     3    13   6.7    -3
# 4   ...     0     1     1     0     0     2     1     6  -0.2    -5
# 5   ...     0     1     2     2     0     3     0    15   8.7    +7
# 6   ...     2     2     4     2     1     3     4     6   0.5    +6
# 7   ...     0     5     4     0     1     3     3    13   3.3    -9
# 8   ...     5    10     6     1     1     3     5    19  18.5    +1
# 9   ...     0     1     4     1     1     2     4    13   7.0    +3
# 10  ...     1     2     2     5     0     3     3    14   8.6    +2
# 11  ...     4     5     4     1     0     3     1    10   6.2    +4
# 12  ...     2     3     3     2     0     4     3    15   7.0    -6
# 13  ...     1     1    11     3     0     2     3     9  11.0     0
# 14  ...     2     5     5     3     0     1     3    15  16.3    +3
# 15  ...     2     4     5     5     0     1     2    13  12.3   -16
# 16  ...     2     3     8     1     1     3     3    15  14.4    +6
# 17  ...     0     5     4     2     0     2     1    12  11.8   +13
# 18  ...     1     2     5     1     0     5     3    10   3.0   -11
# 19  ...     5     9     5     2     0     5     3    19  15.2    +2
# 20  ...     4     7     2     2     0     3     3    30  23.1   -14
# 21  ...     3     8     7     2     0     6     3     6   2.2    -2
# 22  ...     3     3     6     2     0     0     4    15  15.5   -14
# 23  ...     2     8     6     0     0     3     1    19  17.6    +3
# 24  ...     0     0     2     1     0     2     4     2  -0.9    -8
# 25  ...     2     7     2     2     0     4     1    11   7.6    -7
# 26  ...     4     4     8     1     0     5     0    19  15.4   +17
# 27  ...     4     6    11     0     0     5     2    24  19.7    +3
# 28  ...     1     3     6     1     0     3     4    11   5.1   -15
# 29  ...     3     5     4     0     0     5     1    14   6.2    +6
# ..  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 56  ...    11    14    11     1     2     5     3    44  39.5   -15
# 57  ...    13    15     8     2     1     5     6    43  33.7    +9
# 58  ...     9    10     4     1     1     7     5    41  24.1    -1
# 59  ...    10    14     9     0     0     7     5    22  16.9   -16
# 60  ...    11    11    11     1     1     4     3    23  15.7    -3
# 61  ...     8     9     8     1     0     7     2    19  10.6   -15
# 62  ...     4     6     5     3     1     4     3    22  14.6    -1
# 63  ...    11    13     6     0     0     2     3    38  28.5    -2
# 64  ...     6     7     3     0     0     8     5    37  16.8    +1
# 65  ...     8     8     7     0     1     1     6    32  24.5    -4
# 66  ...    11    11     8     1     1     3     2    23  18.9   +10
# 67  ...     9    12    11     3     0     5     3    31  28.2   +18
# 68  ...    13    14    11     4     2     4     2    19  22.5    -1
# 69  ...     8     8     9     1     1     4     5     7   0.6   -18
# 70  ...  None  None  None  None  None  None  None  None  None  None
# 71  ...     9    11     6     1     0     9     3    42  26.0    -7
# 72  ...     8    12    13     4     1     3     3    18  20.8   +18
# 73  ...     5     5     7     0     0     1     3    16   7.4   -20
# 74  ...    10    11    12     2     1     2     0    17  21.3    +8
# 75  ...     6     9     9     2     0     3     3    27  23.6    -1
# 76  ...     9    11    11     2     0     3     2    25  25.3    -3
# 77  ...    15    20    21     3     0     2     2    20  29.6   +24
# 78  ...     7     8    15     1     0     4     2    19  16.7    +4
# 79  ...     9    10    15     1     0     4     3    27  24.5    -1
# 80  ...    10    12    10     0     0     3     4    29  24.1    +3
# 81  ...    11    11    17     1     1     4     3    15  21.7    +6
# 0   ...    12    16     7     2     1     3     3    24  23.1     0
# 1   ...    10    10    13     1     0     4     3    28  27.2    -7
# 2   ...     7    12     9     1     0     5     4    21  19.3   +19
# 3   ...     6    10    12     2     1     4     2    17  18.7    +2
#
# [890 rows x 30 columns]

# %%
sea_stats("2014")
# Out:
#      G        Date     Age   Tm HA  Opp       WL            GS     MP    FG  \
# 0       2013-10-30  24-352  OKC  @  UTA   W (+3)      Inactive   None  None
# 1       2013-11-01  24-354  OKC  @  MIN  L (-19)      Inactive   None  None
# 2    1  2013-11-03  24-356  OKC     PHO   W (+7)             1  32:45     5
# 3    2  2013-11-06  24-359  OKC     DAL  W (+14)             1  32:45    10
# 4    3  2013-11-08  24-361  OKC  @  DET   W (+9)             1  30:05     5
# 5    4  2013-11-10  24-363  OKC     WAS   W (+1)             1  30:01     4
# 6    5  2013-11-13  25-001  OKC  @  LAC   L (-8)             1  34:49     7
# 7    6  2013-11-14  25-002  OKC  @  GSW   L (-1)             1  35:58    13
# 8    7  2013-11-16  25-004  OKC  @  MIL  W (+13)             1  33:14    10
..  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 52  ...  None  None  None  None  None  None  None  None  None  None
# 53  ...  None  None  None  None  None  None  None  None  None  None
# 54  ...  None  None  None  None  None  None  None  None  None  None
# 55  ...     2     5     2     3     0     4     1    14   9.4   -10
# 56  ...     3     5     6     1     0     3     5    13   7.2   -14
# 57  ...     2     3     9     0     0     3     1    24  19.5    +1
# 58  ...     2     2     6     3     0     1     1    21  21.4    +4
# 59  ...     2     2     5     2     0     5     2    26  21.9   +17
# 60  ...     9    10    14     3     0     6     2    13  17.7   +25
# 61  ...     7     9     9     4     0     3     1    36  36.2   +16
# 62  ...     4     7     8     3     0     8     4    20   8.6    -7
# 63  ...     4     4     7     4     0     5     2    24  19.7    +7
# 64  ...     1     2     9     3     1     3     2    29  27.1   +17
# 65  ...  None  None  None  None  None  None  None  None  None  None
# 66  ...     9     9     9     0     0     2     4    17  13.8   +22
# 67  ...  None  None  None  None  None  None  None  None  None  None
# 68  ...     2     3     1     1     0     3     0    15   7.9    +2
# 69  ...  None  None  None  None  None  None  None  None  None  None
# 70  ...     6     7     8     3     0     8     5    23  14.3   -16
# 71  ...     5     5     6     0     0     4     2    18  13.3   +14
# 72  ...     5     5     4     1     0     2     3    19  15.4   +19
# 73  ...     1     1     6     4     0     2     1    27  23.1    +2
# 74  ...  None  None  None  None  None  None  None  None  None  None
# 75  ...     3     4     8     0     2     5     6    33  20.4    -9
# 76  ...  None  None  None  None  None  None  None  None  None  None
# 77  ...     8    11     6     2     0     1     2    30  26.1   +15
# 78  ...     3     5     7     0     1     1     2    24  22.2   +14
# 79  ...     5     9     7     1     0     4     2    21  12.7    +4
# 80  ...  None  None  None  None  None  None  None  None  None  None
# 81  ...     3     6     8     6     0     4     3    22  21.7    +7
#
# [82 rows x 29 columns]

# %%
sea_stats("2014")
# Out:
# None

# %%
headers = headers[1:]

# %%
headers
# Out:
# ['G',
#  'Date',
#  'Age',
#  'Tm',
#  'HA',
#  'Opp',
#  'WL',
#  'GS',
#  'MP',
#  'FG',
#  'FGA',
#  'FG%',
#  '3P',
#  '3PA',
#  '3P%',
#  'FT',
#  'FTA',
#  'FT%',
#  'ORB',
#  'DRB',
#  'TRB',
#  'AST',
#  'STL',
#  'BLK',
#  'TOV',
#  'PF',
#  'PTS',
#  'GmSc',
#  '+/-']

# %%
season_stat
# Out:
# [['1',
#   '2015-10-28',
#   '26-350',
#   'OKC',
#   '',
#   'SAS',
#   'W (+6)',
#   '1',
#   '36:59',
#   '12',
#   '23',
#   '.522',
#   '3',
#   '6',
#   '.500',
#   '6',
#   '7',
#   '.857',
#   '1',
#   '1',
#   '2',
#   '10',
#   '2',
#   '0',
#   '5',
#   '3',
#   '33',
#   '25.1',
#   '+7'],
#  ['2',
#   '2015-10-30',
#   '26-352',
#   'OKC',
#   '@',
#   'ORL',
#   'W (+3)',
#   '1',
#   '47:35',
#   '17',
#   '36',
#   '.472',
#   '1',
#   '5',
#   '.200',
#   '13',
#   '16',
#   '.813',
#   '5',
#   '6',
#   '11',
#   '8',
#   '1',
#   '1',
#   '6',
#   '3',
#   '48',
#   '33.8',
#   '+2'],
#  ['3',
#   '2015-11-01',
#   '26-354',
#   'OKC',
#   '',
#   'DEN',
#   'W (+24)',
#   '1',
#   '25:26',
#   '7',
#   '13',
#   '.538',
#   '1',
#   '4',
#   '.250',
#   '0',
#   '0',
#   '',
#   '2',
#   '7',
#   '9',
#   '8',
#   '3',
#   '0',
#   '4',
#   '0',
#   '15',
#   '16.8',
#   '+22'],
#  ['4',
#   '2015-11-02',
#   '26-355',
#   'OKC',
#   '@',
#   'HOU',
#   'L (-5)',
#   '1',
#   '31:57',
#   '10',
#   '16',
#   '.625',
#   '3',
#   '6',
#   '.500',
#   '2',
#   '2',
#   '1.000',
#   '2',
#   '6',
#   '8',
#   '11',
#   '2',
#   '0',
#   '7',
#   '5',
#   '25',
#   '21.7',
#   '+4'],
#  ['5',
#   '2015-11-04',
#   '26-357',
#   'OKC',
#   '',
#   'TOR',
#   'L (-5)',
#   '1',
#   '35:20',
#   '8',
#   '21',
#   '.381',
#   '3',
#   '9',
#   '.333',
#   '3',
#   '4',
#   '.750',
#   '0',
#   '5',
#   '5',
#   '16',
#   '2',
#   '0',
#   '8',
#   '4',
#   '22',
#   '15.2',
#   '+3'],
#  ['6',
#   '2015-11-05',
#   '26-358',
#   'OKC',
#   '@',
#   'CHI',
#   'L (-6)',
#   '1',
#   '38:34',
#   '7',
#   '18',
#   '.389',
#   '0',
#   '2',
#   '.000',
#   '6',
#   '6',
#   '1.000',
#   '2',
#   '6',
#   '8',
#   '10',
#   '1',
#   '0',
#   '2',
#   '2',
#   '20',
#   '18.6',
#   '+8'],
#  ['7',
#   '2015-11-08',
#   '26-361',
#   'OKC',
#   '',
#   'PHO',
#   'W (+21)',
#   '1',
#   '33:58',
#   '9',
#   '20',
#   '.450',
#   '0',
#   '3',
#   '.000',
#   '3',
#   '4',
#   '.750',
#   '4',
#   '2',
#   '6',
#   '13',
#   '4',
#   '0',
#   '2',
#   '3',
#   '21',
#   '23.5',
#   '+26'],
#  ['8',
#   '2015-11-10',
#   '26-363',
#   'OKC',
#   '@',
#   'WAS',
#   'W (+24)',
#   '1',
#   '27:46',
#   '7',
#   '17',
#   '.412',
#   '3',
#   '4',
#   '.750',
#   '5',
#   '6',
#   '.833',
#   '2',
#   '9',
#   '11',
#   '11',
#   '1',
#   '0',
#   '5',
#   '0',
#   '22',
#   '20.3',
#   '+23'],
#  ['9',
#   '2015-11-13',
#   '27-001',
#   'OKC',
#   '',
#   'PHI',
#   'W (+17)',
#   '1',
#   '34:47',
#   '8',
#   '22',
#   '.364',
#   '2',
#   '6',
#   '.333',
#   '3',
#   '4',
#   '.750',
#   '4',
#   '13',
#   '17',
#   '11',
#   '3',
#   '0',
#   '6',
#   '1',
#   '21',
#   '19.4',
#   '+16'],
#  ['10',
#   '2015-11-15',
#   '27-003',
#   'OKC',
#   '',
#   'BOS',
#   'L (-15)',
#   '1',
#   '32:37',
#   '5',
#   '20',
#   '.250',
#   '2',
#   '10',
#   '.200',
#   '15',
#   '17',
#   '.882',
#   '1',
#   '3',
#   '4',
#   '5',
#   '3',
#   '2',
#   '4',
#   '4',
#   '27',
#   '18.1',
#   '-7'],
#  ['11',
#   '2015-11-16',
#   '27-004',
#   'OKC',
#   '@',
#   'MEM',
#   'L (-8)',
#   '1',
#   '38:32',
#   '13',
#   '19',
#   '.684',
#   '5',
#   '8',
#   '.625',
#   '9',
#   '13',
#   '.692',
#   '1',
#   '3',
#   '4',
#   '14',
#   '3',
#   '0',
#   '8',
#   '1',
#   '40',
#   '36.3',
#   '+2'],
#  ['12',
#   '2015-11-18',
#   '27-006',
#   'OKC',
#   '',
#   'NOP',
#   'W (+7)',
#   '1',
#   '36:04',
#   '14',
#   '25',
#   '.560',
#   '0',
#   '3',
#   '.000',
#   '15',
#   '20',
#   '.750',
#   '3',
#   '6',
#   '9',
#   '8',
#   '1',
#   '1',
#   '4',
#   '1',
#   '43',
#   '35.9',
#   '-5'],
#  ['13',
#   '2015-11-20',
#   '27-008',
#   'OKC',
#   '',
#   'NYK',
#   'L (-3)',
#   '1',
#   '37:37',
#   '11',
#   '29',
#   '.379',
#   '2',
#   '10',
#   '.200',
#   '10',
#   '12',
#   '.833',
#   '3',
#   '4',
#   '7',
#   '7',
#   '4',
#   '1',
#   '3',
#   '4',
#   '34',
#   '25.6',
#   '+4'],
#  ['14',
#   '2015-11-22',
#   '27-010',
#   'OKC',
#   '',
#   'DAL',
#   'W (+3)',
#   '1',
#   '36:53',
#   '12',
#   '22',
#   '.545',
#   '2',
#   '5',
#   '.400',
#   '5',
#   '6',
#   '.833',
#   '0',
#   '5',
#   '5',
#   '11',
#   '5',
#   '1',
#   '7',
#   '1',
#   '31',
#   '27.5',
#   '+4'],
#  ['15',
#   '2015-11-23',
#   '27-011',
#   'OKC',
#   '@',
#   'UTA',
#   'W (+22)',
#   '1',
#   '27:18',
#   '5',
#   '10',
#   '.500',
#   '0',
#   '2',
#   '.000',
#   '10',
#   '10',
#   '1.000',
#   '2',
#   '5',
#   '7',
#   '9',
#   '1',
#   '0',
#   '4',
#   '3',
#   '20',
#   '20.0',
#   '+9'],
#  ['16',
#   '2015-11-25',
#   '27-013',
#   'OKC',
#   '',
#   'BRK',
#   'W (+11)',
#   '1',
#   '35:14',
#   '10',
#   '16',
#   '.625',
#   '0',
#   '3',
#   '.000',
#   '7',
#   '8',
#   '.875',
#   '1',
#   '5',
#   '6',
#   '13',
#   '5',
#   '0',
#   '3',
#   '1',
#   '27',
#   '32.3',
#   '+16'],
#  ['17',
#   '2015-11-27',
#   '27-015',
#   'OKC',
#   '',
#   'DET',
#   'W (+16)',
#   '1',
#   '28:37',
#   '5',
#   '14',
#   '.357',
#   '1',
#   '3',
#   '.333',
#   '3',
#   '5',
#   '.600',
#   '2',
#   '2',
#   '4',
#   '4',
#   '1',
#   '0',
#   '11',
#   '6',
#   '14',
#   '-2.2',
#   '+9'],
#  ['18',
#   '2015-11-30',
#   '27-018',
#   'OKC',
#   '@',
#   'ATL',
#   'L (-6)',
#   '1',
#   '35:57',
#   '11',
#   '24',
#   '.458',
#   '1',
#   '5',
#   '.200',
#   '11',
#   '11',
#   '1.000',
#   '2',
#   '9',
#   '11',
#   '7',
#   '2',
#   '0',
#   '6',
#   '3',
#   '34',
#   '25.4',
#   '-2'],
#  ['19',
#   '2015-12-03',
#   '27-021',
#   'OKC',
#   '@',
#   'MIA',
#   'L (-2)',
#   '1',
#   '34:27',
#   '8',
#   '18',
#   '.444',
#   '0',
#   '3',
#   '.000',
#   '9',
#   '9',
#   '1.000',
#   '1',
#   '4',
#   '5',
#   '6',
#   '1',
#   '0',
#   '7',
#   '1',
#   '25',
#   '15.3',
#   '+8'],
#  ['20',
#   '2015-12-06',
#   '27-024',
#   'OKC',
#   '',
#   'SAC',
#   'W (+3)',
#   '1',
#   '37:52',
#   '7',
#   '13',
#   '.538',
#   '1',
#   '3',
#   '.333',
#   '4',
#   '5',
#   '.800',
#   '0',
#   '11',
#   '11',
#   '10',
#   '3',
#   '0',
#   '3',
#   '2',
#   '19',
#   '21.8',
#   '+13'],
#  ['21',
#   '2015-12-08',
#   '27-026',
#   'OKC',
#   '@',
#   'MEM',
#   'W (+37)',
#   '1',
#   '24:56',
#   '5',
#   '7',
#   '.714',
#   '1',
#   '2',
#   '.500',
#   '2',
#   '2',
#   '1.000',
#   '1',
#   '4',
#   '5',
#   '16',
#   '2',
#   '0',
#   '3',
#   '1',
#   '13',
#   '21.8',
#   '+26'],
#  ['22',
#   '2015-12-10',
#   '27-028',
#   'OKC',
#   '',
#   'ATL',
#   'W (+13)',
#   '1',
#   '38:28',
#   '8',
#   '17',
#   '.471',
#   '3',
#   '4',
#   '.750',
#   '4',
#   '6',
#   '.667',
#   '2',
#   '4',
#   '6',
#   '10',
#   '3',
#   '0',
#   '2',
#   '2',
#   '23',
#   '23.3',
#   '+15'],
#  ['23',
#   '2015-12-11',
#   '27-029',
#   'OKC',
#   '@',
#   'UTA',
#   'W (+4)',
#   '1',
#   '35:02',
#   '8',
#   '19',
#   '.421',
#   '2',
#   '4',
#   '.500',
#   '6',
#   '6',
#   '1.000',
#   '1',
#   '6',
#   '7',
#   '7',
#   '2',
#   '0',
#   '3',
#   '2',
#   '24',
#   '19.5',
#   '+8'],
#  ['24',
#   '2015-12-13',
#   '27-031',
#   'OKC',
#   '',
#   'UTA',
#   'W (+6)',
#   '1',
#   '40:22',
#   '9',
#   '25',
#   '.360',
#   '0',
#   '4',
#   '.000',
#   '7',
#   '9',
#   '.778',
#   '2',
#   '9',
#   '11',
#   '5',
#   '2',
#   '2',
#   '1',
#   '2',
#   '25',
#   '19.5',
#   '+19'],
#  ['25',
#   '2015-12-16',
#   '27-034',
#   'OKC',
#   '',
#   'POR',
#   'W (+16)',
#   '1',
#   '26:53',
#   '5',
#   '15',
#   '.333',
#   '0',
#   '3',
#   '.000',
#   '3',
#   '3',
#   '1.000',
#   '1',
#   '2',
#   '3',
#   '5',
#   '2',
#   '2',
#   '3',
#   '2',
#   '13',
#   '8.9',
#   '+12'],
#  ['26',
#   '2015-12-17',
#   '27-035',
#   'OKC',
#   '@',
#   'CLE',
#   'L (-4)',
#   '1',
#   '34:28',
#   '10',
#   '18',
#   '.556',
#   '1',
#   '3',
#   '.333',
#   '6',
#   '6',
#   '1.000',
#   '0',
#   '3',
#   '3',
#   '10',
#   '3',
#   '0',
#   '4',
#   '4',
#   '27',
#   '23.7',
#   '-4'],
#  ['27',
#   '2015-12-19',
#   '27-037',
#   'OKC',
#   '',
#   'LAL',
#   'W (+40)',
#   '1',
#   '27:43',
#   '5',
#   '11',
#   '.455',
#   '0',
#   '1',
#   '.000',
#   '3',
#   '6',
#   '.500',
#   '0',
#   '1',
#   '1',
#   '11',
#   '1',
#   '0',
#   '4',
#   '2',
#   '13',
#   '10.3',
#   '+18'],
#  ['28',
#   '2015-12-21',
#   '27-039',
#   'OKC',
#   '@',
#   'LAC',
#   'W (+1)',
#   '1',
#   '37:19',
#   '11',
#   '25',
#   '.440',
#   '2',
#   '5',
#   '.400',
#   '9',
#   '11',
#   '.818',
#   '1',
#   '4',
#   '5',
#   '7',
#   '3',
#   '0',
#   '1',
#   '4',
#   '33',
#   '26.3',
#   '+8'],
#  ['29',
#   '2015-12-23',
#   '27-041',
#   'OKC',
#   '@',
#   'LAL',
#   'W (+35)',
#   '1',
#   '29:33',
#   '10',
#   '19',
#   '.526',
#   '0',
#   '1',
#   '.000',
#   '3',
#   '5',
#   '.600',
#   '3',
#   '5',
#   '8',
#   '8',
#   '2',
#   '0',
#   '2',
#   '2',
#   '23',
#   '21.3',
#   '+33'],
#  ['30',
#   '2015-12-25',
#   '27-043',
#   'OKC',
#   '',
#   'CHI',
#   'L (-9)',
#   '1',
#   '39:57',
#   '9',
#   '23',
#   '.391',
#   '1',
#   '7',
#   '.143',
#   '7',
#   '13',
#   '.538',
#   '1',
#   '6',
#   '7',
#   '8',
#   '6',
#   '0',
#   '6',
#   '3',
#   '26',
#   '18.0',
#   '-5'],
#  ['31',
#   '2015-12-27',
#   '27-045',
#   'OKC',
#   '',
#   'DEN',
#   'W (+10)',
#   '1',
#   '38:06',
#   '11',
#   '18',
#   '.611',
#   '2',
#   '3',
#   '.667',
#   '6',
#   '6',
#   '1.000',
#   '1',
#   '8',
#   '9',
#   '12',
#   '1',
#   '0',
#   '4',
#   '0',
#   '30',
#   '30.3',
#   '+14'],
#  ['32',
#   '2015-12-29',
#   '27-047',
#   'OKC',
#   '',
#   'MIL',
#   'W (+8)',
#   '1',
#   '34:47',
#   '10',
#   '22',
#   '.455',
#   '0',
#   '2',
#   '.000',
#   '7',
#   '8',
#   '.875',
#   '1',
#   '6',
#   '7',
#   '7',
#   '5',
#   '0',
#   '3',
#   '1',
#   '27',
#   '24.2',
#   '+5'],
#  ['33',
#   '2015-12-31',
#   '27-049',
#   'OKC',
#   '',
#   'PHO',
#   'W (+4)',
#   '1',
#   '34:28',
#   '12',
#   '19',
#   '.632',
#   '1',
#   '3',
#   '.333',
#   '11',
#   '11',
#   '1.000',
#   '0',
#   '1',
#   '1',
#   '12',
#   '5',
#   '1',
#   '2',
#   '1',
#   '36',
#   '39.5',
#   '+11'],
#  ['34',
#   '2016-01-02',
#   '27-051',
#   'OKC',
#   '@',
#   'CHO',
#   'W (+19)',
#   '1',
#   '30:47',
#   '4',
#   '15',
#   '.267',
#   '1',
#   '3',
#   '.333',
#   '7',
#   '8',
#   '.875',
#   '1',
#   '5',
#   '6',
#   '7',
#   '1',
#   '0',
#   '2',
#   '2',
#   '16',
#   '12.0',
#   '+16'],
#  ['35',
#   '2016-01-04',
#   '27-053',
#   'OKC',
#   '',
#   'SAC',
#   'L (-12)',
#   '1',
#   '41:09',
#   '6',
#   '23',
#   '.261',
#   '2',
#   '9',
#   '.222',
#   '3',
#   '3',
#   '1.000',
#   '1',
#   '7',
#   '8',
#   '15',
#   '1',
#   '0',
#   '7',
#   '4',
#   '17',
#   '9.0',
#   '+5'],
#  ['36',
#   '2016-01-06',
#   '27-055',
#   'OKC',
#   '',
#   'MEM',
#   'W (+18)',
#   '1',
#   '29:55',
#   '7',
#   '17',
#   '.412',
#   '0',
#   '2',
#   '.000',
#   '6',
#   '6',
#   '1.000',
#   '2',
#   '5',
#   '7',
#   '7',
#   '2',
#   '0',
#   '3',
#   '3',
#   '20',
#   '16.5',
#   '+15'],
#  ['37',
#   '2016-01-08',
#   '27-057',
#   'OKC',
#   '@',
#   'LAL',
#   'W (+4)',
#   '1',
#   '34:34',
#   '11',
#   '24',
#   '.458',
#   '1',
#   '4',
#   '.250',
#   '13',
#   '16',
#   '.813',
#   '3',
#   '9',
#   '12',
#   '7',
#   '1',
#   '0',
#   '6',
#   '1',
#   '36',
#   '26.7',
#   '+1'],
#  ['38',
#   '2016-01-10',
#   '27-059',
#   'OKC',
#   '@',
#   'POR',
#   'L (-5)',
#   '1',
#   '38:13',
#   '7',
#   '19',
#   '.368',
#   '2',
#   '4',
#   '.500',
#   '9',
#   '11',
#   '.818',
#   '1',
#   '8',
#   '9',
#   '15',
#   '3',
#   '0',
#   '4',
#   '6',
#   '25',
#   '23.9',
#   '+3'],
#  ['39',
#   '2016-01-12',
#   '27-061',
#   'OKC',
#   '@',
#   'MIN',
#   'W (+5)',
#   '1',
#   '33:19',
#   '8',
#   '15',
#   '.533',
#   '2',
#   '4',
#   '.500',
#   '4',
#   '6',
#   '.667',
#   '1',
#   '6',
#   '7',
#   '11',
#   '3',
#   '0',
#   '7',
#   '3',
#   '22',
#   '18.9',
#   '+11'],
#  ['40',
#   '2016-01-13',
#   '27-062',
#   'OKC',
#   '',
#   'DAL',
#   'W (+19)',
#   '1',
#   '14:40',
#   '0',
#   '3',
#   '.000',
#   '0',
#   '0',
#   '',
#   '0',
#   '4',
#   '.000',
#   '1',
#   '6',
#   '7',
#   '8',
#   '2',
#   '0',
#   '1',
#   '0',
#   '0',
#   '5.4',
#   '+20'],
#  ['41',
#   '2016-01-15',
#   '27-064',
#   'OKC',
#   '',
#   'MIN',
#   'W (+20)',
#   '1',
#   '27:12',
#   '6',
#   '10',
#   '.600',
#   '0',
#   '1',
#   '.000',
#   '0',
#   '0',
#   '',
#   '3',
#   '8',
#   '11',
#   '10',
#   '2',
#   '0',
#   '2',
#   '4',
#   '12',
#   '17.3',
#   '+21'],
#  ['42',
#   '2016-01-17',
#   '27-066',
#   'OKC',
#   '',
#   'MIA',
#   'W (+25)',
#   '1',
#   '33:23',
#   '5',
#   '16',
#   '.313',
#   '1',
#   '4',
#   '.250',
#   '2',
#   '2',
#   '1.000',
#   '3',
#   '7',
#   '10',
#   '15',
#   '2',
#   '0',
#   '3',
#   '2',
#   '13',
#   '16.7',
#   '+15'],
#  ['43',
#   '2016-01-19',
#   '27-068',
#   'OKC',
#   '@',
#   'DEN',
#   'W (+6)',
#   '1',
#   '38:45',
#   '10',
#   '22',
#   '.455',
#   '1',
#   '6',
#   '.167',
#   '6',
#   '9',
#   '.667',
#   '4',
#   '1',
#   '5',
#   '12',
#   '3',
#   '0',
#   '4',
#   '5',
#   '27',
#   '22.9',
#   '+5'],
#  ['44',
#   '2016-01-20',
#   '27-069',
#   'OKC',
#   '',
#   'CHO',
#   'W (+14)',
#   '1',
#   '27:20',
#   '5',
#   '14',
#   '.357',
#   '0',
#   '3',
#   '.000',
#   '6',
#   '7',
#   '.857',
#   '1',
#   '7',
#   '8',
#   '15',
#   '5',
#   '0',
#   '5',
#   '2',
#   '16',
#   '20.3',
#   '+18'],
#  ['45',
#   '2016-01-22',
#   '27-071',
#   'OKC',
#   '@',
#   'DAL',
#   'W (+3)',
#   '1',
#   '34:36',
#   '8',
#   '19',
#   '.421',
#   '0',
#   '4',
#   '.000',
#   '0',
#   '0',
#   '',
#   '3',
#   '5',
#   '8',
#   '7',
#   '2',
#   '1',
#   '4',
#   '4',
#   '16',
#   '11.5',
#   '-9'],
#  ['46',
#   '2016-01-24',
#   '27-073',
#   'OKC',
#   '@',
#   'BRK',
#   'L (-10)',
#   '1',
#   '39:41',
#   '12',
#   '27',
#   '.444',
#   '1',
#   '4',
#   '.250',
#   '2',
#   '5',
#   '.400',
#   '2',
#   '9',
#   '11',
#   '7',
#   '1',
#   '0',
#   '3',
#   '1',
#   '27',
#   '18.3',
#   '-15'],
#  ['47',
#   '2016-01-26',
#   '27-075',
#   'OKC',
#   '@',
#   'NYK',
#   'W (+6)',
#   '1',
#   '44:16',
#   '13',
#   '24',
#   '.542',
#   '0',
#   '2',
#   '.000',
#   '4',
#   '5',
#   '.800',
#   '2',
#   '6',
#   '8',
#   '10',
#   '3',
#   '0',
#   '5',
#   '3',
#   '30',
#   '25.0',
#   '+18'],
#  ['48',
#   '2016-01-27',
#   '27-076',
#   'OKC',
#   '@',
#   'MIN',
#   'W (+3)',
#   '1',
#   '36:40',
#   '7',
#   '13',
#   '.538',
#   '3',
#   '4',
#   '.750',
#   '7',
#   '7',
#   '1.000',
#   '2',
#   '6',
#   '8',
#   '15',
#   '0',
#   '0',
#   '4',
#   '3',
#   '24',
#   '26.2',
#   '+1'],
#  ['49',
#   '2016-01-29',
#   '27-078',
#   'OKC',
#   '',
#   'HOU',
#   'W (+8)',
#   '1',
#   '37:07',
#   '9',
#   '21',
#   '.429',
#   '1',
#   '2',
#   '.500',
#   '7',
#   '10',
#   '.700',
#   '1',
#   '9',
#   '10',
#   '14',
#   '1',
#   '1',
#   '8',
#   '3',
#   '26',
#   '19.4',
#   '+6'],
#  ['50',
#   '2016-02-01',
#   '27-081',
#   'OKC',
#   '',
#   'WAS',
#   'W (+16)',
#   '1',
#   '36:08',
#   '8',
#   '13',
#   '.615',
#   '0',
#   '3',
#   '.000',
#   '1',
#   '1',
#   '1.000',
#   '1',
#   '12',
#   '13',
#   '11',
#   '1',
#   '0',
#   '5',
#   '2',
#   '17',
#   '18.3',
#   '+14'],
#  ['51',
#   '2016-02-03',
#   '27-083',
#   'OKC',
#   '',
#   'ORL',
#   'W (+3)',
#   '1',
#   '37:41',
#   '10',
#   '18',
#   '.556',
#   '0',
#   '1',
#   '.000',
#   '4',
#   '4',
#   '1.000',
#   '7',
#   '12',
#   '19',
#   '14',
#   '2',
#   '0',
#   '2',
#   '1',
#   '24',
#   '33.3',
#   '+10'],
#  ['52',
#   '2016-02-06',
#   '27-086',
#   'OKC',
#   '@',
#   'GSW',
#   'L (-8)',
#   '1',
#   '37:24',
#   '8',
#   '22',
#   '.364',
#   '2',
#   '4',
#   '.500',
#   '9',
#   '9',
#   '1.000',
#   '2',
#   '1',
#   '3',
#   '12',
#   '3',
#   '0',
#   '3',
#   '4',
#   '27',
#   '23.3',
#   '-5'],
#  ['53',
#   '2016-02-08',
#   '27-088',
#   'OKC',
#   '@',
#   'PHO',
#   'W (+16)',
#   '1',
#   '36:14',
#   '8',
#   '19',
#   '.421',
#   '2',
#   '5',
#   '.400',
#   '11',
#   '12',
#   '.917',
#   '3',
#   '5',
#   '8',
#   '8',
#   '2',
#   '0',
#   '6',
#   '4',
#   '29',
#   '22.1',
#   '+1'],
#  ['54',
#   '2016-02-11',
#   '27-091',
#   'OKC',
#   '',
#   'NOP',
#   'W (+26)',
#   '1',
#   '28:25',
#   '8',
#   '14',
#   '.571',
#   '2',
#   '5',
#   '.400',
#   '5',
#   '6',
#   '.833',
#   '1',
#   '8',
#   '9',
#   '10',
#   '0',
#   '0',
#   '2',
#   '2',
#   '23',
#   '23.3',
#   '+19'],
#  ['55',
#   '2016-02-19',
#   '27-099',
#   'OKC',
#   '',
#   'IND',
#   'L (-3)',
#   '1',
#   '37:09',
#   '10',
#   '17',
#   '.588',
#   '1',
#   '4',
#   '.250',
#   '2',
#   '2',
#   '1.000',
#   '0',
#   '3',
#   '3',
#   '18',
#   '2',
#   '1',
#   '2',
#   '2',
#   '23',
#   '28.5',
#   '-4'],
#  ['56',
#   '2016-02-21',
#   '27-101',
#   'OKC',
#   '',
#   'CLE',
#   'L (-23)',
#   '1',
#   '33:04',
#   '7',
#   '15',
#   '.467',
#   '1',
#   '3',
#   '.333',
#   '5',
#   '6',
#   '.833',
#   '3',
#   '6',
#   '9',
#   '11',
#   '1',
#   '0',
#   '1',
#   '3',
#   '20',
#   '22.3',
#   '-16'],
#  ['57',
#   '2016-02-24',
#   '27-104',
#   'OKC',
#   '@',
#   'DAL',
#   'W (+13)',
#   '1',
#   '36:09',
#   '8',
#   '17',
#   '.471',
#   '2',
#   '5',
#   '.400',
#   '6',
#   '6',
#   '1.000',
#   '2',
#   '5',
#   '7',
#   '13',
#   '0',
#   '0',
#   '2',
#   '4',
#   '24',
#   '23.7',
#   '+9'],
#  ['58',
#   '2016-02-25',
#   '27-105',
#   'OKC',
#   '@',
#   'NOP',
#   'L (-4)',
#   '1',
#   '37:37',
#   '15',
#   '25',
#   '.600',
#   '3',
#   '5',
#   '.600',
#   '11',
#   '14',
#   '.786',
#   '2',
#   '2',
#   '4',
#   '9',
#   '0',
#   '0',
#   '2',
#   '3',
#   '44',
#   '36.4',
#   '+6'],
#  ['59',
#   '2016-02-27',
#   '27-107',
#   'OKC',
#   '',
#   'GSW',
#   'L (-3)',
#   '1',
#   '42:11',
#   '10',
#   '29',
#   '.345',
#   '0',
#   '6',
#   '.000',
#   '6',
#   '8',
#   '.750',
#   '3',
#   '4',
#   '7',
#   '13',
#   '2',
#   '0',
#   '7',
#   '4',
#   '26',
#   '14.7',
#   '-5'],
#  ['60',
#   '2016-02-29',
#   '27-109',
#   'OKC',
#   '@',
#   'SAC',
#   'W (+15)',
#   '1',
#   '34:35',
#   '6',
#   '8',
#   '.750',
#   '2',
#   '3',
#   '.667',
#   '6',
#   '7',
#   '.857',
#   '2',
#   '11',
#   '13',
#   '15',
#   '3',
#   '0',
#   '7',
#   '2',
#   '20',
#   '26.8',
#   '+2'],
#  ['61',
#   '2016-03-02',
#   '27-111',
#   'OKC',
#   '@',
#   'LAC',
#   'L (-5)',
#   '1',
#   '36:51',
#   '8',
#   '21',
#   '.381',
#   '2',
#   '7',
#   '.286',
#   '6',
#   '6',
#   '1.000',
#   '0',
#   '6',
#   '6',
#   '12',
#   '1',
#   '0',
#   '5',
#   '4',
#   '24',
#   '17.1',
#   '-7'],
#  ['62',
#   '2016-03-03',
#   '27-112',
#   'OKC',
#   '@',
#   'GSW',
#   'L (-15)',
#   '1',
#   '36:03',
#   '8',
#   '24',
#   '.333',
#   '1',
#   '8',
#   '.125',
#   '5',
#   '7',
#   '.714',
#   '1',
#   '5',
#   '6',
#   '7',
#   '0',
#   '1',
#   '2',
#   '4',
#   '22',
#   '11.8',
#   '-6'],
#  ['63',
#   '2016-03-06',
#   '27-115',
#   'OKC',
#   '@',
#   'MIL',
#   'W (+8)',
#   '1',
#   '38:50',
#   '3',
#   '7',
#   '.429',
#   '1',
#   '3',
#   '.333',
#   '8',
#   '11',
#   '.727',
#   '2',
#   '8',
#   '10',
#   '11',
#   '1',
#   '1',
#   '7',
#   '4',
#   '15',
#   '14.7',
#   '+15'],
#  ['64',
#   '2016-03-09',
#   '27-118',
#   'OKC',
#   '',
#   'LAC',
#   'W (+12)',
#   '1',
#   '37:02',
#   '9',
#   '15',
#   '.600',
#   '0',
#   '2',
#   '.000',
#   '7',
#   '7',
#   '1.000',
#   '2',
#   '9',
#   '11',
#   '19',
#   '2',
#   '1',
#   '7',
#   '2',
#   '25',
#   '30.4',
#   '0'],
#  ['65',
#   '2016-03-11',
#   '27-120',
#   'OKC',
#   '',
#   'MIN',
#   'L (-3)',
#   '1',
#   '37:10',
#   '8',
#   '19',
#   '.421',
#   '3',
#   '6',
#   '.500',
#   '7',
#   '8',
#   '.875',
#   '0',
#   '4',
#   '4',
#   '8',
#   '0',
#   '0',
#   '5',
#   '4',
#   '26',
#   '15.7',
#   '-10'],
#  ['66',
#   '2016-03-12',
#   '27-121',
#   'OKC',
#   '@',
#   'SAS',
#   'L (-8)',
#   '1',
#   '38:14',
#   '5',
#   '16',
#   '.313',
#   '1',
#   '4',
#   '.250',
#   '8',
#   '10',
#   '.800',
#   '3',
#   '3',
#   '6',
#   '7',
#   '2',
#   '0',
#   '9',
#   '3',
#   '19',
#   '8.7',
#   '-1'],
#  ['67',
#   '2016-03-14',
#   '27-123',
#   'OKC',
#   '',
#   'POR',
#   'W (+34)',
#   '1',
#   '28:27',
#   '7',
#   '11',
#   '.636',
#   '0',
#   '0',
#   '',
#   '3',
#   '6',
#   '.500',
#   '2',
#   '8',
#   '10',
#   '16',
#   '2',
#   '1',
#   '0',
#   '2',
#   '17',
#   '27.8',
#   '+16'],
#  ['68',
#   '2016-03-16',
#   '27-125',
#   'OKC',
#   '@',
#   'BOS',
#   'W (+21)',
#   '1',
#   '26:09',
#   '8',
#   '16',
#   '.500',
#   '4',
#   '7',
#   '.571',
#   '4',
#   '8',
#   '.500',
#   '1',
#   '4',
#   '5',
#   '5',
#   '3',
#   '0',
#   '2',
#   '1',
#   '24',
#   '20.4',
#   '+15'],
#  ['69',
#   '2016-03-18',
#   '27-127',
#   'OKC',
#   '@',
#   'PHI',
#   'W (+14)',
#   '1',
#   '32:26',
#   '8',
#   '20',
#   '.400',
#   '2',
#   '5',
#   '.400',
#   '2',
#   '4',
#   '.500',
#   '3',
#   '12',
#   '15',
#   '10',
#   '1',
#   '2',
#   '5',
#   '2',
#   '20',
#   '17.7',
#   '+27'],
#  ['70',
#   '2016-03-19',
#   '27-128',
#   'OKC',
#   '@',
#   'IND',
#   'W (+4)',
#   '1',
#   '35:56',
#   '4',
#   '17',
#   '.235',
#   '3',
#   '9',
#   '.333',
#   '3',
#   '4',
#   '.750',
#   '3',
#   '8',
#   '11',
#   '14',
#   '1',
#   '0',
#   '7',
#   '4',
#   '14',
#   '10.0',
#   '-2'],
#  ['71',
#   '2016-03-22',
#   '27-131',
#   'OKC',
#   '',
#   'HOU',
#   'W (+4)',
#   '1',
#   '36:52',
#   '7',
#   '18',
#   '.389',
#   '0',
#   '7',
#   '.000',
#   '7',
#   '8',
#   '.875',
#   '3',
#   '9',
#   '12',
#   '15',
#   '1',
#   '0',
#   '4',
#   '1',
#   '21',
#   '22.7',
#   '-5'],
#  ['72',
#   '2016-03-24',
#   '27-133',
#   'OKC',
#   '',
#   'UTA',
#   'W (+22)',
#   '1',
#   '27:15',
#   '6',
#   '15',
#   '.400',
#   '1',
#   '3',
#   '.333',
#   '2',
#   '3',
#   '.667',
#   '1',
#   '6',
#   '7',
#   '9',
#   '3',
#   '0',
#   '2',
#   '1',
#   '15',
#   '15.9',
#   '+16'],
#  ['73',
#   '2016-03-26',
#   '27-135',
#   'OKC',
#   '',
#   'SAS',
#   'W (+19)',
#   '1',
#   '34:25',
#   '10',
#   '18',
#   '.556',
#   '0',
#   '2',
#   '.000',
#   '9',
#   '9',
#   '1.000',
#   '2',
#   '4',
#   '6',
#   '8',
#   '1',
#   '0',
#   '2',
#   '1',
#   '29',
#   '27.2',
#   '+30'],
#  ['74',
#   '2016-03-28',
#   '27-137',
#   'OKC',
#   '@',
#   'TOR',
#   'W (+19)',
#   '1',
#   '34:06',
#   '10',
#   '16',
#   '.625',
#   '1',
#   '3',
#   '.333',
#   '5',
#   '8',
#   '.625',
#   '3',
#   '7',
#   '10',
#   '12',
#   '1',
#   '0',
#   '3',
#   '1',
#   '26',
#   '27.8',
#   '+35'],
#  ['75',
#   '2016-03-29',
#   '27-138',
#   'OKC',
#   '@',
#   'DET',
#   'L (-6)',
#   '1',
#   '34:42',
#   '8',
#   '28',
#   '.286',
#   '2',
#   '8',
#   '.250',
#   '6',
#   '9',
#   '.667',
#   '2',
#   '2',
#   '4',
#   '6',
#   '1',
#   '0',
#   '3',
#   '4',
#   '24',
#   '9.0',
#   '-20'],
#  ['76',
#   '2016-03-31',
#   '27-140',
#   'OKC',
#   '',
#   'LAC',
#   'W (+2)',
#   '1',
#   '35:49',
#   '8',
#   '18',
#   '.444',
#   '3',
#   '7',
#   '.429',
#   '7',
#   '7',
#   '1.000',
#   '1',
#   '7',
#   '8',
#   '11',
#   '4',
#   '0',
#   '5',
#   '0',
#   '26',
#   '26.1',
#   '-4'],
#  ['77',
#   '2016-04-03',
#   '27-143',
#   'OKC',
#   '@',
#   'HOU',
#   'L (-8)',
#   '1',
#   '37:24',
#   '8',
#   '15',
#   '.533',
#   '1',
#   '4',
#   '.250',
#   '6',
#   '7',
#   '.857',
#   '3',
#   '10',
#   '13',
#   '9',
#   '2',
#   '0',
#   '8',
#   '3',
#   '23',
#   '19.5',
#   '-8'],
#  ['78',
#   '2016-04-05',
#   '27-145',
#   'OKC',
#   '@',
#   'DEN',
#   'W (+22)',
#   '1',
#   '26:41',
#   '4',
#   '9',
#   '.444',
#   '2',
#   '4',
#   '.500',
#   '3',
#   '5',
#   '.600',
#   '3',
#   '11',
#   '14',
#   '12',
#   '2',
#   '0',
#   '5',
#   '1',
#   '13',
#   '17.9',
#   '+26'],
#  ['', '2016-04-06', '27-146', 'OKC', '@', 'POR', 'L (-5)', 'Did Not Play'],
#  ['79',
#   '2016-04-09',
#   '27-149',
#   'OKC',
#   '@',
#   'SAC',
#   'L (-2)',
#   '1',
#   '33:42',
#   '7',
#   '15',
#   '.467',
#   '1',
#   '5',
#   '.200',
#   '9',
#   '10',
#   '.900',
#   '1',
#   '4',
#   '5',
#   '10',
#   '1',
#   '0',
#   '8',
#   '5',
#   '24',
#   '15.8',
#   '+3'],
#  ['80',
#   '2016-04-11',
#   '27-151',
#   'OKC',
#   '',
#   'LAL',
#   'W (+33)',
#   '1',
#   '27:39',
#   '5',
#   '13',
#   '.385',
#   '0',
#   '5',
#   '.000',
#   '3',
#   '5',
#   '.600',
#   '0',
#   '10',
#   '10',
#   '14',
#   '1',
#   '0',
#   '3',
#   '2',
#   '13',
#   '15.1',
#   '+27'],
#  ['', '2016-04-12', '27-152', 'OKC', '@', 'SAS', 'L (-4)', 'Not With Team']]

# %%
pd.DataFrame(season_stat,columns=headers)
# Out:
#      G        Date     Age   Tm HA  Opp       WL             GS     MP    FG  \
# 0    1  2015-10-28  26-350  OKC     SAS   W (+6)              1  36:59    12
# 1    2  2015-10-30  26-352  OKC  @  ORL   W (+3)              1  47:35    17
# 2    3  2015-11-01  26-354  OKC     DEN  W (+24)              1  25:26     7
# 3    4  2015-11-02  26-355  OKC  @  HOU   L (-5)              1  31:57    10
# 4    5  2015-11-04  26-357  OKC     TOR   L (-5)              1  35:20     8
# 5    6  2015-11-05  26-358  OKC  @  CHI   L (-6)              1  38:34     7
# 6    7  2015-11-08  26-361  OKC     PHO  W (+21)              1  33:58     9
# 7    8  2015-11-10  26-363  OKC  @  WAS  W (+24)              1  27:46     7
# 8    9  2015-11-13  27-001  OKC     PHI  W (+17)              1  34:47     8
# 9   10  2015-11-15  27-003  OKC     BOS  L (-15)              1  32:37     5
# 10  11  2015-11-16  27-004  OKC  @  MEM   L (-8)              1  38:32    13
# 11  12  2015-11-18  27-006  OKC     NOP   W (+7)              1  36:04    14
# 12  13  2015-11-20  27-008  OKC     NYK   L (-3)              1  37:37    11
# 13  14  2015-11-22  27-010  OKC     DAL   W (+3)              1  36:53    12
# 14  15  2015-11-23  27-011  OKC  @  UTA  W (+22)              1  27:18     5
# 15  16  2015-11-25  27-013  OKC     BRK  W (+11)              1  35:14    10
# 16  17  2015-11-27  27-015  OKC     DET  W (+16)              1  28:37     5
# 17  18  2015-11-30  27-018  OKC  @  ATL   L (-6)              1  35:57    11
# 18  19  2015-12-03  27-021  OKC  @  MIA   L (-2)              1  34:27     8
# 19  20  2015-12-06  27-024  OKC     SAC   W (+3)              1  37:52     7
...   DRB   TRB   AST   STL   BLK   TOV    PF   PTS  GmSc   +/-
# 0   ...     1     2    10     2     0     5     3    33  25.1    +7
# 1   ...     6    11     8     1     1     6     3    48  33.8    +2
# 2   ...     7     9     8     3     0     4     0    15  16.8   +22
# 3   ...     6     8    11     2     0     7     5    25  21.7    +4
# 4   ...     5     5    16     2     0     8     4    22  15.2    +3
# 5   ...     6     8    10     1     0     2     2    20  18.6    +8
# 6   ...     2     6    13     4     0     2     3    21  23.5   +26
# 7   ...     9    11    11     1     0     5     0    22  20.3   +23
# 8   ...    13    17    11     3     0     6     1    21  19.4   +16
# 9   ...     3     4     5     3     2     4     4    27  18.1    -7
# 10  ...     3     4    14     3     0     8     1    40  36.3    +2
# 11  ...     6     9     8     1     1     4     1    43  35.9    -5
# 12  ...     4     7     7     4     1     3     4    34  25.6    +4
# 13  ...     5     5    11     5     1     7     1    31  27.5    +4
# 14  ...     5     7     9     1     0     4     3    20  20.0    +9
# 15  ...     5     6    13     5     0     3     1    27  32.3   +16
# 16  ...     2     4     4     1     0    11     6    14  -2.2    +9
# 17  ...     9    11     7     2     0     6     3    34  25.4    -2
# 18  ...     4     5     6     1     0     7     1    25  15.3    +8
# 19  ...    11    11    10     3     0     3     2    19  21.8   +13
# 20  ...     4     5    16     2     0     3     1    13  21.8   +26
# 21  ...     4     6    10     3     0     2     2    23  23.3   +15
# 22  ...     6     7     7     2     0     3     2    24  19.5    +8
# 23  ...     9    11     5     2     2     1     2    25  19.5   +19
# 24  ...     2     3     5     2     2     3     2    13   8.9   +12
# 25  ...     3     3    10     3     0     4     4    27  23.7    -4
# 26  ...     1     1    11     1     0     4     2    13  10.3   +18
# 27  ...     4     5     7     3     0     1     4    33  26.3    +8
# 28  ...     5     8     8     2     0     2     2    23  21.3   +33
# 29  ...     6     7     8     6     0     6     3    26  18.0    -5
# ..  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 52  ...     5     8     8     2     0     6     4    29  22.1    +1
# 53  ...     8     9    10     0     0     2     2    23  23.3   +19
# 54  ...     3     3    18     2     1     2     2    23  28.5    -4
# 55  ...     6     9    11     1     0     1     3    20  22.3   -16
# 56  ...     5     7    13     0     0     2     4    24  23.7    +9
# 57  ...     2     4     9     0     0     2     3    44  36.4    +6
# 58  ...     4     7    13     2     0     7     4    26  14.7    -5
# 59  ...    11    13    15     3     0     7     2    20  26.8    +2
# 60  ...     6     6    12     1     0     5     4    24  17.1    -7
# 61  ...     5     6     7     0     1     2     4    22  11.8    -6
# 62  ...     8    10    11     1     1     7     4    15  14.7   +15
# 63  ...     9    11    19     2     1     7     2    25  30.4     0
# 64  ...     4     4     8     0     0     5     4    26  15.7   -10
# 65  ...     3     6     7     2     0     9     3    19   8.7    -1
# 66  ...     8    10    16     2     1     0     2    17  27.8   +16
# 67  ...     4     5     5     3     0     2     1    24  20.4   +15
# 68  ...    12    15    10     1     2     5     2    20  17.7   +27
# 69  ...     8    11    14     1     0     7     4    14  10.0    -2
# 70  ...     9    12    15     1     0     4     1    21  22.7    -5
# 71  ...     6     7     9     3     0     2     1    15  15.9   +16
# 72  ...     4     6     8     1     0     2     1    29  27.2   +30
# 73  ...     7    10    12     1     0     3     1    26  27.8   +35
# 74  ...     2     4     6     1     0     3     4    24   9.0   -20
# 75  ...     7     8    11     4     0     5     0    26  26.1    -4
# 76  ...    10    13     9     2     0     8     3    23  19.5    -8
# 77  ...    11    14    12     2     0     5     1    13  17.9   +26
# 78  ...  None  None  None  None  None  None  None  None  None  None
# 79  ...     4     5    10     1     0     8     5    24  15.8    +3
# 80  ...    10    10    14     1     0     3     2    13  15.1   +27
# 81  ...  None  None  None  None  None  None  None  None  None  None
#
# [82 rows x 29 columns]

# %% [markdown]
# # Getting all players who are playing in current 2020 season

# %%
player_current_page = requests.get("https://www.basketball-reference.com/leagues/NBA_2020_per_game.html")
player_names = BeautifulSoup(player_current_page.text,'lxml')
players = player_names.find("div", {"id": "all_per_game_stats"}).find_all('tr')

# %%
links_names = []
for i in range(len(players)):
    try:
        for a in players[i].find_all('td')[0].find_all('a',href=True):
            links_names.append(a['href'].split('.')[0])
    except:
        IndexError

# %%
links_names

# %%
links_names_test = links_names[:10]
# Out:
# ['/players/a/adamsst01',
#  '/players/a/adebaba01',
#  '/players/a/aldrila01',
#  '/players/a/alexani01',
#  '/players/a/allengr01',
#  '/players/a/allenja01',
#  '/players/a/aminual01',
#  '/players/a/anderky01',
#  '/players/a/anderry01',
#  '/players/a/antetgi01']

# %%
def sea_stats(player,year):
    playa = requests.get("https://www.basketball-reference.com"+player+"/gamelog/"+year)
    #player_year = requests.get("https://www.basketball-reference.com/players/w/westbru01/gamelog/" + year)
    player_games = BeautifulSoup(playa.text,'lxml')
    games = player_games.find("div", {"id": "all_pgl_basic"}).find_all('tr')
    
    headers = []
    season_stats = []

    for w in games[0].find_all('th'):
        entry = w.getText()
        headers.append(entry)

    headers[5] = "HA"
    headers[7] = "WL"
    
    headers = headers[1:] # To get headers
    
    for i in range(1,len(games)):
        game_stats = []
        for j in games[i].find_all('td'):
            game_stats.append(j.getText())
        season_stats.append(game_stats)
    
    season_stat = [x for x in season_stats if x] # To remove empty rows
    
    return pd.DataFrame(season_stat,columns=headers)

# %%
def all_seasons(player):
    
    list_of_seasons = []
    
    for i in active_years:
        try:
            stats = sea_stats(player,i)
            list_of_seasons.append(stats)
        except:
            AttributeError
            
    result = pd.concat(list_of_seasons)
    
    player_name = player.split("/")[3]
    
    result.insert(0,"Name",player_name)
    
    return result

# %%
all_players = []
for name in links_names_test:
    all_players.append(all_seasons(name))

# %%
pd.concat(all_players)
# Out:
#          Name   G        Date     Age   Tm HA  Opp       WL             GS  \
# 0   adamsst01   1  2015-10-28  22-100  OKC     SAS   W (+6)              1
# 1   adamsst01   2  2015-10-30  22-102  OKC  @  ORL   W (+3)              1
# 2   adamsst01   3  2015-11-01  22-104  OKC     DEN  W (+24)              1
# 3   adamsst01   4  2015-11-02  22-105  OKC  @  HOU   L (-5)              1
# 4   adamsst01   5  2015-11-04  22-107  OKC     TOR   L (-5)              1
# 5   adamsst01   6  2015-11-05  22-108  OKC  @  CHI   L (-6)              1
# ..    ...  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 56  38:02  ...    12    19    11     2     1     2     1    33  38.5   +19
# 57  36:44  ...    11    13     6     1     2     4     2    30  26.4   -10
# 58  32:44  ...     9    10     7     1     2     3     2    27  26.3   +15
# 59   None  ...  None  None  None  None  None  None  None  None  None  None
# 60  24:19  ...     6     7     2     0     2     1     0    17  14.9   -24
# 61  32:30  ...    13    15     6     0     3     4     4    16  14.2    +3
# 62  31:57  ...    11    14     8     2     1     4     3    43  36.1   +19
# 63  33:39  ...    11    13     6     3     0     6     6    21  15.9    -5
# 64  33:00  ...    11    12     5     0     1     6     3    29  22.1   +20
# 65  29:48  ...    10    13     6     1     1     5     3    26  25.9   +14
# 66  35:12  ...    10    13     6     0     1     0     2    27  26.0    -4
# 67  26:03  ...     7     9     5     0     0     6     4    24  17.1   +17
# 68  34:47  ...    14    16     9     2     3     6     4    33  31.7   +19
# 69  36:12  ...    15    16     7     2     1     1     1    52  50.4   +12
# 70   None  ...  None  None  None  None  None  None  None  None  None  None
# 71   None  ...  None  None  None  None  None  None  None  None  None  None
# 72  28:28  ...     6     8     7     1     2     3     3    27  24.0    +7
# 73  31:36  ...    10    10     7     0     4     4     3    26  23.9   +23
# 74  32:40  ...    12    14     4     1     1     5     3    19  13.8    +7
# 75  31:56  ...     9     9     5     1     1     1     3    34  30.3    +1
# 76   None  ...  None  None  None  None  None  None  None  None  None  None
# 77  29:58  ...     6    11     2     1     1     4     4    28  17.5    +6
# 78  34:58  ...    13    13     6     0     5     0     2    45  43.6    +9
# 79   None  ...  None  None  None  None  None  None  None  None  None  None
# 80  24:36  ...     6     9     3     1     3     1     0    30  30.0   +16
# 81   None  ...  None  None  None  None  None  None  None  None  None  None
# 0   28:10  ...    13    13    11     1     1     3     6    30  28.4    +8
# 1   36:38  ...    14    17     9     3     2     8     6    29  24.1     0
# 2   29:12  ...     9    10     7     0     2     2     2    14  10.8   +10
# 3   34:38  ...    13    14     5     1     2     3     4    22  20.4    -4
#
# [2423 rows x 30 columns]

# %%
all_seasons(links_names_test[0])
# Out:
#          Name   G        Date     Age   Tm HA  Opp       WL        GS     MP  \
# 0   adamsst01   1  2015-10-28  22-100  OKC     SAS   W (+6)         1  29:34
# 1   adamsst01   2  2015-10-30  22-102  OKC  @  ORL   W (+3)         1  35:54
# 2   adamsst01   3  2015-11-01  22-104  OKC     DEN  W (+24)         1  21:32
# 3   adamsst01   4  2015-11-02  22-105  OKC  @  HOU   L (-5)         1  19:12
# 4   adamsst01   5  2015-11-04  22-107  OKC     TOR   L (-5)         1  26:36
# 5   adamsst01   6  2015-11-05  22-108  OKC  @  CHI   L (-6)         1  24:58
# 6   adamsst01   7  2015-11-08  22-111  OKC     PHO  W (+21)         1  19:31
# 7   adamsst01   8  2015-11-10  22-113  OKC  @  WAS  W (+24)         1  20:36
# 8   adamsst01   9  2015-11-13  22-116  OKC     PHI  W (+17)         1  25:59
# 71  adamsst01  70  2019-03-20  25-243  OKC     TOR   L (-9)         1  39:58
# 72  adamsst01  71  2019-03-22  25-245  OKC  @  TOR   W (+7)         1  33:08
# 73  adamsst01  72  2019-03-25  25-248  OKC  @  MEM  L (-12)         1  31:54
# 74  adamsst01  73  2019-03-27  25-250  OKC     IND   W (+8)         1  34:46
# 75  adamsst01  74  2019-03-29  25-252  OKC     DEN  L (-10)         1  34:40
# 76  adamsst01  75  2019-03-31  25-254  OKC     DAL   L (-3)         1  38:41
# 77  adamsst01  76  2019-04-02  25-256  OKC     LAL  W (+16)         1  33:11
# 78  adamsst01  77  2019-04-05  25-259  OKC     DET  W (+13)         1  23:55
# 79  adamsst01  78  2019-04-07  25-261  OKC  @  MIN   W (+6)         1  27:28
# 80  adamsst01  79  2019-04-09  25-263  OKC     HOU   W (+1)         1  36:33
# 81  adamsst01  80  2019-04-10  25-264  OKC  @  MIL  W (+11)         1  12:21
# 0   adamsst01   1  2019-10-23  26-095  OKC  @  UTA   L (-5)         1  27:42
# 1   adamsst01   2  2019-10-25  26-097  OKC     WAS  L (-12)         1  29:10
# 2   adamsst01   3  2019-10-27  26-099  OKC     GSW  W (+28)         1  25:24
# 3   adamsst01   4  2019-10-28  26-100  OKC  @  HOU   L (-4)         1  26:48
# 4   adamsst01      2019-10-30  26-102  OKC     POR   L (-3)  Inactive   None
#
#     ...   DRB   TRB   AST   STL   BLK   TOV    PF   PTS  GmSc   +/-
# 0   ...     6     7     1     0     1     2     4     6   4.7    +4
# 1   ...     3     8     2     2     2     2     5     9  11.5    -3
# 2   ...     0     3     1     0     2     2     4     2   0.1   +24
# 3   ...     3     3     0     1     0     0     1     5   4.8    -8
# 4   ...     4     7     1     0     4     2     3    10  10.7    +8
# 5   ...     6     6     1     0     2     0     1     6   7.9   +11
# 6   ...     2     5     1     0     5     2     1     7   8.5   +12
# 7   ...     4     6     0     1     1     0     4     4   4.6    +5
# 8   ...     1     2     0     1     3     0     5     6   5.1   +19
# 9   ...     5     7     3     0     0     1     2     6   8.4    -1
# 10  ...     2     7     1     0     1     2     6    14  12.4    -4
# 11  ...     1     2     0     0     1     0     1     0  -0.1    +2
# 12  ...     4     8     0     0     1     0     3     4   4.4    -3
# 13  ...     2     4     3     0     0     1     4     6   5.1    -7
# 14  ...     2     3     0     0     3     0     4     7   6.1   +13
# 15  ...     4     4     1     1     2     0     3     4   4.7    -6
# 16  ...     9    13     1     0     1     0     2     8  12.2   +12
# 17  ...     2     2     0     0     0     0     1     0  -1.3   -14
# 18  ...     5     8     0     0     0     1     2     9   8.8    +3
# 19  ...     6    12     1     1     1     0     3     6   8.8   +14
# 20  ...     1     5     0     1     0     1     2     4   2.4   +12
# 21  ...     5     7     1     1     0     0     1    11  11.5    +9
# 22  ...     1     4     0     0     0     0     3     4   3.2     0
# 23  ...     6     7     0     0     2     1     3     9   7.7   +17
# 24  ...     6    12     0     0     1     1     3    11  11.9   +17
# 25  ...     2     5     0     0     1     2     6     4   1.7    +3
# 26  ...     4     7     0     0     0     0     3    10  10.1   +15
# 27  ...     7    11     0     0     1     1     3     6   6.0     0
# 28  ...     5     7     1     1     2     2     2     6   6.5   +39
# 29  ...     3     4     0     0     0     0     2     3   1.0   -24
# ..  ...   ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 57  ...     3    10     3     5     1     3     2    16  18.0   +19
# 58  ...     5     9     1     0     0     1     2    11  10.5    -2
# 59  ...     1     5     2     1     1     3     5    15  10.2   -23
# 60  ...     6    14     1     1     0     3     1    11  10.8    -5
# 61  ...     7    13     0     2     1     2     4    17  16.7   -12
# 62  ...    14    22     0     2     1     4     1    13  14.5    -3
# 63  ...     2    11     2     1     3     3     0    13  16.8   -16
# 64  ...     2     7     0     2     2     1     4    12  11.6    +4
# 65  ...     3    10     3     0     0     1     6     6   7.4   -21
# 66  ...     4     7     0     2     2     3     4    12   9.5   +14
# 67  ...     1     7     1     2     1     2     2    13  11.7   +11
# 68  ...     5     8     1     0     0     4     3    17   9.1    -7
# 69  ...     2     9     1     1     2     2     1     9  10.7   -19
# 70  ...     8    12     3     1     2     2     6    10  12.3    +4
# 71  ...     0     7     2     1     0     2     3     4   4.0    -4
# 72  ...     1     5     1     2     3     1     2     9  10.0   +10
# 73  ...     2     8     0     4     3     1     2     2   6.6   -20
# 74  ...     5    12     3     2     1     0     1    25  29.2   +13
# 75  ...     3     5     2     0     1     1     0    16  13.8    +2
# 76  ...     6    15     2     0     2     0     2    20  21.0   +10
# 77  ...     1     8     3     1     5     2     2    13  14.3   +26
# 78  ...     6    14     0     0     2     2     4    14  15.7    +1
# 79  ...     4     6     1     1     0     3     6     8   5.0   +31
# 80  ...     5    13     1     0     0     0     1     8   8.1    +2
# 81  ...     0     2     0     0     1     0     1     4   1.8    -1
# 0   ...     8    11     2     1     0     2     4     3  -0.9    -1
# 1   ...    10    14     0     1     1     1     1     7   7.6    -2
# 2   ...     5    10     3     0     0     1     2     8   8.5   +26
# 3   ...    10    12     1     0     2     1     3     6   5.4    -5
# 4   ...  None  None  None  None  None  None  None  None  None  None
#
# [333 rows x 30 columns]

# %%
active_years = []
for i in range(1996,2021):
    active_years.append(str(i))

# %%
list_of_seasons = []

for i in active_years:
    list_of_seasons.append(sea_stats(i))

# %%
result = pd.concat(list_of_seasons)

# %%
my_list = []
for i in games[1].find_all('td'):
    my_list.append(i)

# %%
player_year = requests.get("https://www.basketball-reference.com/players/w/westbru01/gamelog/" + "1999")
player_games = BeautifulSoup(player_year.text,'lxml')
try:
    games = player_games.find("div", {"id": "all_pgl_basic"}).find_all('tr')
except:
    AttributeError

# %%
player_year
# Out:
# <Response [200]>

# %%
my_list
# Out:
# ['Steven Adams',
#  'C',
#  '26',
#  'OKC',
#  '4',
#  '4',
#  '27.3',
#  '2.5',
#  '8.0',
#  '.313',
#  '0.0',
#  '0.0',
#  '',
#  '2.5',
#  '8.0',
#  '.313',
#  '.313',
#  '1.0',
#  '3.5',
#  '.286',
#  '3.5',
#  '8.3',
#  '11.8',
#  '1.5',
#  '0.5',
#  '0.8',
#  '1.3',
#  '2.5',
#  '6.0']

# %%
games.find_all('a', href=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-08cea422e02d> in <module>()
# ----> 1 games.find_all('a', href=True)
#
# /anaconda/lib/python3.6/site-packages/bs4/element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?
